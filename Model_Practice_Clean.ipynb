# %% [markdown]
# <a href="https://colab.research.google.com/github/pen1064/Toronto_House_Market/blob/main/Model_Practice_Clean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
#house_data = pd.read_csv('house_complete_details_clean.csv')
house_data = pd.read_csv('short_listed.csv')
house_data.head(3)
# Out:
#    sold_price  list_price                    address  bedroom  bathroom  \
# 0   1680000.0   1499000.0              30 Norway Ave        3         3
# 1    600000.0    550000.0        1403 - 76 Shuter St        1         1
# 2    660000.0    599000.0  103 - 80 Marine Parade Dr        1         1
#
#     sqft       type  parking        lat       long                      Line  \
# 0    0.0  Townhouse        1  43.672653 -79.314617            Bloor-Danforth
# 1  249.5      Condo        1  43.655293 -79.384117  Yonge-University-Spadina
# 2  549.5      Condo        1  43.626188 -79.486044            Bloor-Danforth
#
#    Station      Dist                             city_district  mean_income
# 0  Coxwell  1.448304                    Woodbine Corridor (64)      55199.0
# 1   Dundas  0.314122                  Bay Street Corridor (76)      56526.0
# 2     Jane  2.655549  Mimico (includes Humber Bay Shores) (17)      54438.0

# %%
house_data.dropna(subset=["sqft", "sold_price"], inplace=True)
house_data.reset_index(drop=True, inplace=True)

# %%
house_data.dtypes
# Out:
# sold_price       float64
# list_price       float64
# address           object
# bedroom            int64
# bathroom           int64
# sqft             float64
# type              object
# parking            int64
# lat              float64
# long             float64
# Line              object
# Station           object
# Dist             float64
# city_district     object
# mean_income      float64
# dtype: object

# %%
house_data.drop(['address','Station', 'lat', 'long', 'city_district'], axis=1, inplace=True)

# %%
house_data.dropna(['sqft'])
# Out:
# array(['Townhouse', 'Condo', 'Detached', 'Condo Special', 'Plex',
#        'Co Op Apt'], dtype=object)

# %%
d = pd.get_dummies(house_data, columns=['type', 'Line'])
predictors = d.drop(["sold_price", "list_price"], axis = 1).columns
#predictors = d.drop(["sold_price", "final_price_persqft", "list_price"], axis = 1).columns
print(predictors)
# Out:
# Index(['bedroom', 'bathroom', 'sqft', 'parking', 'Dist', 'mean_income',
#        'type_Co Op Apt', 'type_Condo', 'type_Condo Special', 'type_Detached',
#        'type_Plex', 'type_Townhouse', 'Line_Bloor-Danforth', 'Line_Sheppard',
#        'Line_Yonge-University-Spadina'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize=[14, 14])
ax = sns.heatmap(d.corr(), annot=True)

# %%
plt.figure(1); plt.title('sqft')
sns.distplot(d['sqft'], kde=False)


plt.figure(2); plt.title('Johnson Dist')
sns.distplot(d['Dist'], kde=False, fit=stats.johnsonsu)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
attributes=['mean_income', 'Dist', 'sold_price']
for attribute in attributes:
    print(attribute)
    plt.figure(figsize=(15,5))
    x = d[attribute]
    ax1=plt.subplot(1,3,1)
    plt.subplots_adjust(hspace=1)
    sns.distplot(x, fit=stats.norm)
    plt.title(attribute)
    (mu, sigma) = stats.norm.fit(x)
    plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)])

    ax2=plt.subplot(1,3,2)
    stats.probplot(x, dist=stats.norm, plot=ax2)

    ax3=plt.subplot(1,3,3)
    if attribute != 'Dist':
      boxcox_lambda = stats.boxcox_normmax(x, brack=(-2, 2.0),  method='mle')
      transformed_sp = stats.boxcox(x, boxcox_lambda)
    else:
      transformed_sp, johnson_lambdas = stats.yeojohnson(x)
    
    stats.probplot(transformed_sp, dist=stats.norm, plot=ax3)
# Out:
# mean_income
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Dist
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# sold_price
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure()
ax1=plt.subplot(1,2,1)
sns.displot(house_data['bedroom'])

ax2=plt.subplot(1,2,2)
sns.displot(house_data['bathroom'])

# %%
from sklearn.preprocessing import PowerTransformer
house_data_d_copy = d.copy()
#numerics = ['sqft', 'mean_income', 'Dist']
numerics = ['mean_income', 'Dist', 'sold_price']
lambdas=[]
pt = PowerTransformer(method='box-cox')
pt1 = PowerTransformer(method='yeo-johnson')
house_data_d_copy['sold_price'] = house_data_d_copy['sold_price']/100
house_data_d_copy['mean_income'] = house_data_d_copy['mean_income']/10

for numeric_feat in numerics:
  if numeric_feat != 'Dist':
    house_data_d_copy[[numeric_feat]] = pt.fit_transform(house_data_d_copy[[numeric_feat]])
    lambdas.append(pt.lambdas_[0])
  else:
    house_data_d_copy[[numeric_feat]] = pt1.fit_transform(house_data_d_copy[[numeric_feat]])
    lambdas.append(pt1.lambdas_[0])
print(lambdas)
# Out:
# [-0.8008502462344432, -0.45958034456317415, -0.6538988816104838]

# %%
house_data_d_copy.head(5)
# Out:
#    sold_price  list_price  bedroom  bathroom   sqft  parking      Dist  \
# 0    1.177410   1499000.0        3         3    0.0        1  0.043859
# 1   -0.909556    550000.0        1         1  249.5        1 -1.322749
# 2   -0.652196    599000.0        1         1  549.5        1  0.738424
# 3   -0.108842    699000.0        2         1  749.5        1 -1.166948
# 4    0.105979    869000.0        2         2  849.5        1 -1.255324
#
#    mean_income  type_Co Op Apt  type_Condo  type_Condo Special  type_Detached  \
# 0     0.293677               0           0                   0              0
# 1     0.350620               0           1                   0              0
# 2     0.259896               0           1                   0              0
# 3     0.147405               0           1                   0              0
# 4     0.083684               0           1                   0              0
#
#    type_Plex  type_Townhouse  Line_Bloor-Danforth  Line_Sheppard  \
# 0          0               1                    1              0
# 1          0               0                    0              0
# 2          0               0                    1              0
# 3          0               0                    0              1
# 4          0               0                    0              0
#
#    Line_Yonge-University-Spadina
# 0                              0
# 1                              1
# 2                              0
# 3                              0
# 4                              1

# %%
from sklearn.model_selection import train_test_split, cross_validate, KFold
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import make_scorer, mean_absolute_error, mean_squared_error

house_data_d_copy[predictors] = house_data_d_copy[predictors].astype(float)
house_data_d_copy.sold_price =  house_data_d_copy.sold_price.astype(float)


X_train, X_test, y_train, y_test = train_test_split(house_data_d_copy[predictors], 
                                                    house_data_d_copy.sold_price, test_size = 0.3, 
                                                    random_state=33, stratify=house_data_d_copy["type_Condo"].values)
cv_split= KFold(n_splits=10, shuffle=True, random_state=1)

# %%
import xgboost as xgb
clf2 = xgb.XGBRegressor(objective='reg:squarederror', seed=33)
clf2.fit(X_train, y_train)
yhat2 = clf2.predict(X_test)

y_test2 = pt.inverse_transform(pd.DataFrame(y_test, columns=['sold_price'])) * 100
y_pred2 = pt.inverse_transform(pd.DataFrame(yhat2,columns=['sold_price']))  * 100
print(mean_absolute_error(y_test2, y_pred2))
print(np.sqrt(mean_squared_error(y_test2, y_pred2)))
# Out:
# 182909.3115225102
# 401617.2745347273

# %%
clf2.get_params()
# Out:
# {'base_score': 0.5,
#  'booster': 'gbtree',
#  'colsample_bylevel': 1,
#  'colsample_bynode': 1,
#  'colsample_bytree': 1,
#  'gamma': 0,
#  'importance_type': 'gain',
#  'learning_rate': 0.1,
#  'max_delta_step': 0,
#  'max_depth': 3,
#  'min_child_weight': 1,
#  'missing': None,
#  'n_estimators': 100,
#  'n_jobs': 1,
#  'nthread': None,
#  'objective': 'reg:squarederror',
#  'random_state': 0,
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'scale_pos_weight': 1,
#  'seed': 33,
#  'silent': None,
#  'subsample': 1,
#  'verbosity': 1}

# %%
X_train1, X_validation1, y_train1, y_validation1 = train_test_split(X_train, y_train, test_size=0.25)
dtrain = xgb.DMatrix(data=X_train1, label=y_train1)

# %%
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe
space={'max_depth':  hp.uniform('max_depth', 1, 12),
       'learning_rate': hp.uniform('learning_rate', 0.01,0.1),
       'subsample': hp.quniform('subsample', 0.5, 1, 0.05),
        'gamma': hp.uniform ('gamma', 0,9),
        'reg_alpha' : hp.quniform('reg_alpha', 0,150,10),
        'reg_lambda' : hp.uniform('reg_lambda', 0,1),
        'colsample_bytree' : 1, #hp.uniform('colsample_bytree', 0.5,1),
        'min_child_weight' : hp.quniform('min_child_weight', 0, 10, 1),
        'n_estimators': hp.quniform('n_estimators', 100, 500, 50),
        'nthread': 4,
        'seed': 33
    }
def objective(space):
    clf=xgb.XGBRegressor(
                    objective ='reg:squarederror',learning_rate=space['learning_rate'],
                    n_estimators =int(space['n_estimators']), max_depth = int(space['max_depth']), gamma = space['gamma'],
                    reg_alpha = space['reg_alpha'], reg_lambda = space['reg_lambda'], min_child_weight=int(space['min_child_weight']),
                    colsample_bytree=int(space['colsample_bytree']), subsample=space['subsample'])
    
    evaluation = [( X_train1, y_train1), (X_validation1, y_validation1)]
    #dtrain = xgb.DMatrix(data=X_train1, label=y_train1)
    #dvalid = xgb.DMatrix(data=X_validation1, label=y_validation1)
    #watchlist = [(dvalid, 'eval'), (dtrain, 'train')]
#    clf.fit(X_train, y_train,eval_set=evaluation, eval_metric='rmse',early_stopping_rounds=10,verbose=False)
    clf.fit(X_train1, y_train1,eval_set=evaluation, eval_metric='rmse',
            early_stopping_rounds=10,verbose=True)

    pred = clf.predict(X_validation1)

    accuracy = mean_squared_error(y_validation1, pred)

    print ("SCORE:", accuracy)
    return {'loss': accuracy, 'status': STATUS_OK }

# %%
t = Trials()

best_hyperparams = fmin(fn = objective, space = space,
                        algo = tpe.suggest,max_evals = 200,trials = t)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# [55]	validation_0-rmse:0.428289	validation_1-rmse:0.427984
#
# [56]	validation_0-rmse:0.427261	validation_1-rmse:0.427026
#
# [57]	validation_0-rmse:0.426558	validation_1-rmse:0.426285
#
# [58]	validation_0-rmse:0.426088	validation_1-rmse:0.425786
#
# [59]	validation_0-rmse:0.425189	validation_1-rmse:0.424915
#
# [60]	validation_0-rmse:0.424623	validation_1-rmse:0.42432
#
# [61]	validation_0-rmse:0.42421	validation_1-rmse:0.423868
#
# [62]	validation_0-rmse:0.423934	validation_1-rmse:0.423571
#
# [63]	validation_0-rmse:0.423664	validation_1-rmse:0.423305
#
# [64]	validation_0-rmse:0.422958	validation_1-rmse:0.422653
#
# [65]	validation_0-rmse:0.422357	validation_1-rmse:0.422102
#
# [66]	validation_0-rmse:0.421971	validation_1-rmse:0.421769
#
# [67]	validation_0-rmse:0.421574	validation_1-rmse:0.421336
#
# [68]	validation_0-rmse:0.42117	validation_1-rmse:0.420892
#
# [69]	validation_0-rmse:0.420871	validation_1-rmse:0.420555
#
# [70]	validation_0-rmse:0.420431	validation_1-rmse:0.420178
#
# [71]	validation_0-rmse:0.419955	validation_1-rmse:0.419729
#
# [72]	validation_0-rmse:0.419686	validation_1-rmse:0.419476
#
# [73]	validation_0-rmse:0.419488	validation_1-rmse:0.419264
#
# [74]	validation_0-rmse:0.419322	validation_1-rmse:0.419082
#
# [75]	validation_0-rmse:0.418857	validation_1-rmse:0.418678
#
# [76]	validation_0-rmse:0.418539	validation_1-rmse:0.418399
#
# [77]	validation_0-rmse:0.418395	validation_1-rmse:0.418241
#
# [78]	validation_0-rmse:0.418016	validation_1-rmse:0.417892
#
# [79]	validation_0-rmse:0.417776	validation_1-rmse:0.41762
#
# [80]	validation_0-rmse:0.417606	validation_1-rmse:0.417415
#
# [81]	validation_0-rmse:0.417429	validation_1-rmse:0.417225
#
# [82]	validation_0-rmse:0.41723	validation_1-rmse:0.417023
#
# [83]	validation_0-rmse:0.417085	validation_1-rmse:0.416861
#
# [84]	validation_0-rmse:0.416896	validation_1-rmse:0.416702
#
# [85]	validation_0-rmse:0.416565	validation_1-rmse:0.416397
#
# [86]	validation_0-rmse:0.416287	validation_1-rmse:0.416138
#
# [87]	validation_0-rmse:0.416219	validation_1-rmse:0.416064
#
# [88]	validation_0-rmse:0.415951	validation_1-rmse:0.415819
#
# [89]	validation_0-rmse:0.415951	validation_1-rmse:0.415819
#
# [90]	validation_0-rmse:0.415802	validation_1-rmse:0.415648
#
# [91]	validation_0-rmse:0.415744	validation_1-rmse:0.415575
#
# [92]	validation_0-rmse:0.415744	validation_1-rmse:0.415574
#
# [93]	validation_0-rmse:0.415744	validation_1-rmse:0.415574
#
# [94]	validation_0-rmse:0.415744	validation_1-rmse:0.415574
#
# [95]	validation_0-rmse:0.415588	validation_1-rmse:0.415388
#
# [96]	validation_0-rmse:0.415588	validation_1-rmse:0.415388
#
# [97]	validation_0-rmse:0.415464	validation_1-rmse:0.415244
#
# [98]	validation_0-rmse:0.415332	validation_1-rmse:0.415114
#
# [99]	validation_0-rmse:0.415332	validation_1-rmse:0.415114
#
# [100]	validation_0-rmse:0.415332	validation_1-rmse:0.415114
#
# [101]	validation_0-rmse:0.415123	validation_1-rmse:0.414925
#
# [102]	validation_0-rmse:0.415018	validation_1-rmse:0.414803
#
# [103]	validation_0-rmse:0.415018	validation_1-rmse:0.414803
#
# [104]	validation_0-rmse:0.415018	validation_1-rmse:0.414803
#
# [105]	validation_0-rmse:0.41479	validation_1-rmse:0.414592
#
# [106]	validation_0-rmse:0.414563	validation_1-rmse:0.414382
#
# [107]	validation_0-rmse:0.414465	validation_1-rmse:0.414257
#
# [108]	validation_0-rmse:0.414293	validation_1-rmse:0.414104
#
# [109]	validation_0-rmse:0.414208	validation_1-rmse:0.414004
#
# [110]	validation_0-rmse:0.414208	validation_1-rmse:0.414004
#
# [111]	validation_0-rmse:0.414208	validation_1-rmse:0.414004
#
# [112]	validation_0-rmse:0.414208	validation_1-rmse:0.414004
#
# [113]	validation_0-rmse:0.414208	validation_1-rmse:0.414004
#
# [114]	validation_0-rmse:0.414208	validation_1-rmse:0.414004
#
# [115]	validation_0-rmse:0.413936	validation_1-rmse:0.413832
#
# [116]	validation_0-rmse:0.413936	validation_1-rmse:0.413832
#
# [117]	validation_0-rmse:0.413843	validation_1-rmse:0.413721
#
# [118]	validation_0-rmse:0.413692	validation_1-rmse:0.413591
#
# [119]	validation_0-rmse:0.413504	validation_1-rmse:0.413399
#
# [120]	validation_0-rmse:0.413504	validation_1-rmse:0.413399
#
# [121]	validation_0-rmse:0.413504	validation_1-rmse:0.413399
#
# [122]	validation_0-rmse:0.413504	validation_1-rmse:0.413399
#
# [123]	validation_0-rmse:0.413504	validation_1-rmse:0.413399
#
# [124]	validation_0-rmse:0.413353	validation_1-rmse:0.413259
#
# [125]	validation_0-rmse:0.413353	validation_1-rmse:0.413259
#
# [126]	validation_0-rmse:0.413353	validation_1-rmse:0.413259
#
# [127]	validation_0-rmse:0.413353	validation_1-rmse:0.413259
#
# [128]	validation_0-rmse:0.413353	validation_1-rmse:0.413259
#
# [129]	validation_0-rmse:0.413353	validation_1-rmse:0.413259
#
# [130]	validation_0-rmse:0.413353	validation_1-rmse:0.413259
#
# [131]	validation_0-rmse:0.413353	validation_1-rmse:0.413259
#
# [132]	validation_0-rmse:0.413353	validation_1-rmse:0.413259
#
# [133]	validation_0-rmse:0.413353	validation_1-rmse:0.413259
#
# [134]	validation_0-rmse:0.413094	validation_1-rmse:0.413076
#
# [135]	validation_0-rmse:0.413094	validation_1-rmse:0.413076
#
# [136]	validation_0-rmse:0.413024	validation_1-rmse:0.412993
#
# [137]	validation_0-rmse:0.413024	validation_1-rmse:0.412993
#
# [138]	validation_0-rmse:0.413024	validation_1-rmse:0.412993
#
# [139]	validation_0-rmse:0.413024	validation_1-rmse:0.412993
#
# [140]	validation_0-rmse:0.413024	validation_1-rmse:0.412993
#
# [141]	validation_0-rmse:0.413024	validation_1-rmse:0.412993
#
# [142]	validation_0-rmse:0.41289	validation_1-rmse:0.412851
#
# [143]	validation_0-rmse:0.41289	validation_1-rmse:0.412851
#
# [144]	validation_0-rmse:0.41289	validation_1-rmse:0.412851
#
# [145]	validation_0-rmse:0.41289	validation_1-rmse:0.412851
#
# [146]	validation_0-rmse:0.41289	validation_1-rmse:0.412851
#
# [147]	validation_0-rmse:0.41289	validation_1-rmse:0.412851
#
# [148]	validation_0-rmse:0.41289	validation_1-rmse:0.412851
#
# [149]	validation_0-rmse:0.41289	validation_1-rmse:0.412851
#
# [150]	validation_0-rmse:0.41289	validation_1-rmse:0.412851
#
# [151]	validation_0-rmse:0.412693	validation_1-rmse:0.412624
#
# [152]	validation_0-rmse:0.412693	validation_1-rmse:0.412624
#
# [153]	validation_0-rmse:0.412453	validation_1-rmse:0.412435
#
# [154]	validation_0-rmse:0.412453	validation_1-rmse:0.412435
#
# [155]	validation_0-rmse:0.412453	validation_1-rmse:0.412435
#
# [156]	validation_0-rmse:0.412453	validation_1-rmse:0.412435
#
# [157]	validation_0-rmse:0.412453	validation_1-rmse:0.412435
#
# [158]	validation_0-rmse:0.412453	validation_1-rmse:0.412435
#
# [159]	validation_0-rmse:0.412453	validation_1-rmse:0.412435
#
# [160]	validation_0-rmse:0.412453	validation_1-rmse:0.412435
#
# [161]	validation_0-rmse:0.412453	validation_1-rmse:0.412435
#
# [162]	validation_0-rmse:0.412453	validation_1-rmse:0.412435
#
# [163]	validation_0-rmse:0.412453	validation_1-rmse:0.412435
#
# Stopping. Best iteration:
# [153]	validation_0-rmse:0.412453	validation_1-rmse:0.412435
#
#
# SCORE:
# 0.17010242901119255
# [0]	validation_0-rmse:1.08555	validation_1-rmse:1.08376
#
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
#
# [1]	validation_0-rmse:1.05814	validation_1-rmse:1.05662
#
# [2]	validation_0-rmse:1.03164	validation_1-rmse:1.03033
#
# [3]	validation_0-rmse:1.00608	validation_1-rmse:1.00505
#
# [4]	validation_0-rmse:0.981469	validation_1-rmse:0.9807
#
# [5]	validation_0-rmse:0.957838	validation_1-rmse:0.957331
#
# [6]	validation_0-rmse:0.935135	validation_1-rmse:0.934898
#
# [7]	validation_0-rmse:0.913299	validation_1-rmse:0.913326
#
# [8]	validation_0-rmse:0.892362	validation_1-rmse:0.892579
#
# [9]	validation_0-rmse:0.872264	validation_1-rmse:0.872563
#
# [10]	validation_0-rmse:0.85291	validation_1-rmse:0.853439
#
# [11]	validation_0-rmse:0.834416	validation_1-rmse:0.835092
#
# [12]	validation_0-rmse:0.816346	validation_1-rmse:0.817091
#
# [13]	validation_0-rmse:0.79916	validation_1-rmse:0.800046
#
# [14]	validation_0-rmse:0.782702	validation_1-rmse:0.783708
#
# [15]	validation_0-rmse:0.766619	validation_1-rmse:0.76778
#
# [16]	validation_0-rmse:0.751396	validation_1-rmse:0.752639
#
# [17]	validation_0-rmse:0.736847	validation_1-rmse:0.738193
#
# [18]	validation_0-rmse:0.722241	validation_1-rmse:0.723741
#
# [19]	validation_0-rmse:0.709004	validation_1-rmse:0.710507
#
# [20]	validation_0-rmse:0.695681	validation_1-rmse:0.697328
#
# [21]	validation_0-rmse:0.682792	validation_1-rmse:0.684512
#
# [22]	validation_0-rmse:0.671118	validation_1-rmse:0.6729
#
# [23]	validation_0-rmse:0.65916	validation_1-rmse:0.661058
#
# [24]	validation_0-rmse:0.647464	validation_1-rmse:0.649437
#
# [25]	validation_0-rmse:0.636572	validation_1-rmse:0.638656
#
# [26]	validation_0-rmse:0.626743	validation_1-rmse:0.628818
#
# [27]	validation_0-rmse:0.616808	validation_1-rmse:0.618976
#
# [28]	validation_0-rmse:0.606802	validation_1-rmse:0.609198
#
# [29]	validation_0-rmse:0.598111	validation_1-rmse:0.600454
#
# [30]	validation_0-rmse:0.588927	validation_1-rmse:0.591378
#
# [31]	validation_0-rmse:0.580377	validation_1-rmse:0.582873
#
# [32]	validation_0-rmse:0.572078	validation_1-rmse:0.574711
#
# [33]	validation_0-rmse:0.56421	validation_1-rmse:0.566932
#
# [34]	validation_0-rmse:0.556654	validation_1-rmse:0.559472
#
# [35]	validation_0-rmse:0.54975	validation_1-rmse:0.552493
#
# [36]	validation_0-rmse:0.54351	validation_1-rmse:0.546246
#
# [37]	validation_0-rmse:0.537193	validation_1-rmse:0.539992
#
# [38]	validation_0-rmse:0.531038	validation_1-rmse:0.533849
#
# [39]	validation_0-rmse:0.5248	validation_1-rmse:0.527699
#
# [40]	validation_0-rmse:0.518807	validation_1-rmse:0.521804
#
# [41]	validation_0-rmse:0.513328	validation_1-rmse:0.516411
#
# [42]	validation_0-rmse:0.508381	validation_1-rmse:0.511428
#
# [43]	validation_0-rmse:0.503344	validation_1-rmse:0.506454
#
# [44]	validation_0-rmse:0.498411	validation_1-rmse:0.501605
#
# [45]	validation_0-rmse:0.493585	validation_1-rmse:0.496876
#
# [46]	validation_0-rmse:0.489328	validation_1-rmse:0.492752
#
# [47]	validation_0-rmse:0.485212	validation_1-rmse:0.488669
#
# [48]	validation_0-rmse:0.481308	validation_1-rmse:0.484767
#
# [49]	validation_0-rmse:0.477433	validation_1-rmse:0.480957
#
# [50]	validation_0-rmse:0.473714	validation_1-rmse:0.477268
#
# [51]	validation_0-rmse:0.470403	validation_1-rmse:0.473933
#
# [52]	validation_0-rmse:0.467064	validation_1-rmse:0.470693
#
# [53]	validation_0-rmse:0.464109	validation_1-rmse:0.467709
#
# [54]	validation_0-rmse:0.460972	validation_1-rmse:0.464615
#
# [55]	validation_0-rmse:0.458073	validation_1-rmse:0.461758
#
# [56]	validation_0-rmse:0.455474	validation_1-rmse:0.459129
#
# [57]	validation_0-rmse:0.452915	validation_1-rmse:0.456543
#
# [58]	validation_0-rmse:0.450496	validation_1-rmse:0.454071
#
# [59]	validation_0-rmse:0.447882	validation_1-rmse:0.451517
#
# [60]	validation_0-rmse:0.445713	validation_1-rmse:0.449286
#
# [61]	validation_0-rmse:0.443485	validation_1-rmse:0.447062
#
# [62]	validation_0-rmse:0.441389	validation_1-rmse:0.44503
#
# [63]	validation_0-rmse:0.43937	validation_1-rmse:0.443031
#
# [64]	validation_0-rmse:0.437373	validation_1-rmse:0.441098
#
# [65]	validation_0-rmse:0.435365	validation_1-rmse:0.439081
#
# [66]	validation_0-rmse:0.433874	validation_1-rmse:0.437544
#
# [67]	validation_0-rmse:0.432132	validation_1-rmse:0.435893
#
# [68]	validation_0-rmse:0.430588	validation_1-rmse:0.434317
#
# [69]	validation_0-rmse:0.429053	validation_1-rmse:0.432699
#
# [70]	validation_0-rmse:0.427588	validation_1-rmse:0.431253
#
# [71]	validation_0-rmse:0.426172	validation_1-rmse:0.429833
#
# [72]	validation_0-rmse:0.424861	validation_1-rmse:0.428553
#
# [73]	validation_0-rmse:0.423453	validation_1-rmse:0.427215
#
# [74]	validation_0-rmse:0.422264	validation_1-rmse:0.425978
#
# [75]	validation_0-rmse:0.421008	validation_1-rmse:0.424665
#
# [76]	validation_0-rmse:0.41974	validation_1-rmse:0.42343
#
# [77]	validation_0-rmse:0.418517	validation_1-rmse:0.422203
#
# [78]	validation_0-rmse:0.417573	validation_1-rmse:0.421176
#
# [79]	validation_0-rmse:0.416489	validation_1-rmse:0.420056
#
# [80]	validation_0-rmse:0.415465	validation_1-rmse:0.419017
#
# [81]	validation_0-rmse:0.414631	validation_1-rmse:0.418118
#
# [82]	validation_0-rmse:0.413645	validation_1-rmse:0.417109
#
# [83]	validation_0-rmse:0.412972	validation_1-rmse:0.416419
#
# [84]	validation_0-rmse:0.412113	validation_1-rmse:0.415519
#
# [85]	validation_0-rmse:0.41128	validation_1-rmse:0.41469
#
# [86]	validation_0-rmse:0.410357	validation_1-rmse:0.413798
#
# [87]	validation_0-rmse:0.409643	validation_1-rmse:0.413058
#
# [88]	validation_0-rmse:0.408856	validation_1-rmse:0.412272
#
# [89]	validation_0-rmse:0.408061	validation_1-rmse:0.411479
#
# [90]	validation_0-rmse:0.407154	validation_1-rmse:0.410574
#
# [91]	validation_0-rmse:0.406559	validation_1-rmse:0.409934
#
# [92]	validation_0-rmse:0.405909	validation_1-rmse:0.40928
#
# [93]	validation_0-rmse:0.405216	validation_1-rmse:0.408614
#
# [94]	validation_0-rmse:0.404581	validation_1-rmse:0.407973
#
# [95]	validation_0-rmse:0.403972	validation_1-rmse:0.407398
#
# [96]	validation_0-rmse:0.403126	validation_1-rmse:0.406581
#
# [97]	validation_0-rmse:0.402478	validation_1-rmse:0.405928
#
# [98]	validation_0-rmse:0.401945	validation_1-rmse:0.405391
#
# [99]	validation_0-rmse:0.401221	validation_1-rmse:0.404692
#
# [100]	validation_0-rmse:0.400534	validation_1-rmse:0.404006
#
# [101]	validation_0-rmse:0.400006	validation_1-rmse:0.403489
#
# [102]	validation_0-rmse:0.399587	validation_1-rmse:0.403069
#
# [103]	validation_0-rmse:0.399041	validation_1-rmse:0.402515
#
# [104]	validation_0-rmse:0.398598	validation_1-rmse:0.402074
#
# [105]	validation_0-rmse:0.398118	validation_1-rmse:0.401542
#
# [106]	validation_0-rmse:0.397461	validation_1-rmse:0.40086
#
# [107]	validation_0-rmse:0.39695	validation_1-rmse:0.400347
#
# [108]	validation_0-rmse:0.396595	validation_1-rmse:0.400014
#
# [109]	validation_0-rmse:0.396176	validation_1-rmse:0.39962
#
# [110]	validation_0-rmse:0.395782	validation_1-rmse:0.399253
#
# [111]	validation_0-rmse:0.395403	validation_1-rmse:0.398865
#
# [112]	validation_0-rmse:0.394715	validation_1-rmse:0.398199
#
# [113]	validation_0-rmse:0.394364	validation_1-rmse:0.397867
#
# [114]	validation_0-rmse:0.394029	validation_1-rmse:0.397563
#
# [115]	validation_0-rmse:0.393654	validation_1-rmse:0.397158
#
# [116]	validation_0-rmse:0.393297	validation_1-rmse:0.39683
#
# [117]	validation_0-rmse:0.392939	validation_1-rmse:0.396489
#
# [118]	validation_0-rmse:0.392635	validation_1-rmse:0.396212
#
# [119]	validation_0-rmse:0.39245	validation_1-rmse:0.396011
#
# [120]	validation_0-rmse:0.392178	validation_1-rmse:0.395722
#
# [121]	validation_0-rmse:0.391908	validation_1-rmse:0.39547
#
# [122]	validation_0-rmse:0.39146	validation_1-rmse:0.394967
#
# [123]	validation_0-rmse:0.391191	validation_1-rmse:0.394715
#
# [124]	validation_0-rmse:0.390738	validation_1-rmse:0.394288
#
# [125]	validation_0-rmse:0.390375	validation_1-rmse:0.39394
#
# [126]	validation_0-rmse:0.390039	validation_1-rmse:0.3936
#
# [127]	validation_0-rmse:0.38963	validation_1-rmse:0.393224
#
# [128]	validation_0-rmse:0.389297	validation_1-rmse:0.392908
#
# [129]	validation_0-rmse:0.388965	validation_1-rmse:0.392575
#
# [130]	validation_0-rmse:0.388646	validation_1-rmse:0.392288
#
# [131]	validation_0-rmse:0.388343	validation_1-rmse:0.392006
#
# [132]	validation_0-rmse:0.388049	validation_1-rmse:0.391708
#
# [133]	validation_0-rmse:0.387817	validation_1-rmse:0.391481
#
# [134]	validation_0-rmse:0.387506	validation_1-rmse:0.391169
#
# [135]	validation_0-rmse:0.387178	validation_1-rmse:0.390853
#
# [136]	validation_0-rmse:0.386833	validation_1-rmse:0.390498
#
# [137]	validation_0-rmse:0.386701	validation_1-rmse:0.390377
#
# [138]	validation_0-rmse:0.38636	validation_1-rmse:0.390059
#
# [139]	validation_0-rmse:0.386075	validation_1-rmse:0.389779
#
# [140]	validation_0-rmse:0.385803	validation_1-rmse:0.389503
#
# [141]	validation_0-rmse:0.385632	validation_1-rmse:0.389335
#
# [142]	validation_0-rmse:0.385426	validation_1-rmse:0.389153
#
# [143]	validation_0-rmse:0.385255	validation_1-rmse:0.388984
#
# [144]	validation_0-rmse:0.384951	validation_1-rmse:0.388695
#
# [145]	validation_0-rmse:0.384686	validation_1-rmse:0.388459
#
# [146]	validation_0-rmse:0.384492	validation_1-rmse:0.38825
#
# [147]	validation_0-rmse:0.384257	validation_1-rmse:0.388008
#
# [148]	validation_0-rmse:0.384022	validation_1-rmse:0.387762
#
# [149]	validation_0-rmse:0.383853	validation_1-rmse:0.387587
#
# [150]	validation_0-rmse:0.383541	validation_1-rmse:0.387248
#
# [151]	validation_0-rmse:0.383359	validation_1-rmse:0.387079
#
# [152]	validation_0-rmse:0.383123	validation_1-rmse:0.386867
#
# [153]	validation_0-rmse:0.382895	validation_1-rmse:0.386636
#
# [154]	validation_0-rmse:0.382734	validation_1-rmse:0.386459
#
# [155]	validation_0-rmse:0.382409	validation_1-rmse:0.386214
#
# [156]	validation_0-rmse:0.382269	validation_1-rmse:0.386079
#
# [157]	validation_0-rmse:0.382028	validation_1-rmse:0.385848
#
# [158]	validation_0-rmse:0.381826	validation_1-rmse:0.385676
#
# [159]	validation_0-rmse:0.381721	validation_1-rmse:0.385559
#
# [160]	validation_0-rmse:0.381499	validation_1-rmse:0.385352
#
# [161]	validation_0-rmse:0.381255	validation_1-rmse:0.385134
#
# [162]	validation_0-rmse:0.381136	validation_1-rmse:0.385029
#
# [163]	validation_0-rmse:0.380936	validation_1-rmse:0.384847
#
# [164]	validation_0-rmse:0.380838	validation_1-rmse:0.384755
#
# [165]	validation_0-rmse:0.380641	validation_1-rmse:0.384555
#
# [166]	validation_0-rmse:0.380456	validation_1-rmse:0.384375
#
# [167]	validation_0-rmse:0.380371	validation_1-rmse:0.384301
#
# [168]	validation_0-rmse:0.38014	validation_1-rmse:0.384031
#
# [169]	validation_0-rmse:0.380013	validation_1-rmse:0.383881
#
# [170]	validation_0-rmse:0.379959	validation_1-rmse:0.383833
#
# [171]	validation_0-rmse:0.37985	validation_1-rmse:0.383711
#
# [172]	validation_0-rmse:0.379746	validation_1-rmse:0.383592
#
# [173]	validation_0-rmse:0.379474	validation_1-rmse:0.383362
#
# [174]	validation_0-rmse:0.379342	validation_1-rmse:0.383204
#
# [175]	validation_0-rmse:0.379314	validation_1-rmse:0.383168
#
# [176]	validation_0-rmse:0.379181	validation_1-rmse:0.383059
#
# [177]	validation_0-rmse:0.378933	validation_1-rmse:0.382798
#
# [178]	validation_0-rmse:0.378746	validation_1-rmse:0.382661
#
# [179]	validation_0-rmse:0.378544	validation_1-rmse:0.38248
#
# [180]	validation_0-rmse:0.378298	validation_1-rmse:0.382262
#
# [181]	validation_0-rmse:0.378114	validation_1-rmse:0.38207
#
# [182]	validation_0-rmse:0.377931	validation_1-rmse:0.381908
#
# [183]	validation_0-rmse:0.37778	validation_1-rmse:0.381793
#
# [184]	validation_0-rmse:0.377699	validation_1-rmse:0.38174
#
# [185]	validation_0-rmse:0.377572	validation_1-rmse:0.381602
#
# [186]	validation_0-rmse:0.377363	validation_1-rmse:0.381422
#
# [187]	validation_0-rmse:0.377168	validation_1-rmse:0.38125
#
# [188]	validation_0-rmse:0.376933	validation_1-rmse:0.380999
#
# [189]	validation_0-rmse:0.376805	validation_1-rmse:0.380902
#
# [190]	validation_0-rmse:0.376678	validation_1-rmse:0.38079
#
# [191]	validation_0-rmse:0.376552	validation_1-rmse:0.380678
#
# [192]	validation_0-rmse:0.376477	validation_1-rmse:0.380608
#
# [193]	validation_0-rmse:0.376327	validation_1-rmse:0.38047
#
# [194]	validation_0-rmse:0.376295	validation_1-rmse:0.380444
#
# [195]	validation_0-rmse:0.376162	validation_1-rmse:0.380312
#
# [196]	validation_0-rmse:0.376005	validation_1-rmse:0.380189
#
# [197]	validation_0-rmse:0.375941	validation_1-rmse:0.380121
#
# [198]	validation_0-rmse:0.375756	validation_1-rmse:0.379932
#
# [199]	validation_0-rmse:0.375667	validation_1-rmse:0.379858
#
# [200]	validation_0-rmse:0.375538	validation_1-rmse:0.379726
#
# [201]	validation_0-rmse:0.375324	validation_1-rmse:0.379526
#
# [202]	validation_0-rmse:0.375217	validation_1-rmse:0.379438
#
# [203]	validation_0-rmse:0.375025	validation_1-rmse:0.379258
#
# [204]	validation_0-rmse:0.374975	validation_1-rmse:0.379213
#
# [205]	validation_0-rmse:0.374912	validation_1-rmse:0.379138
#
# [206]	validation_0-rmse:0.374848	validation_1-rmse:0.379062
#
# [207]	validation_0-rmse:0.374762	validation_1-rmse:0.378985
#
# [208]	validation_0-rmse:0.374603	validation_1-rmse:0.378854
#
# [209]	validation_0-rmse:0.374441	validation_1-rmse:0.378729
#
# [210]	validation_0-rmse:0.37433	validation_1-rmse:0.37862
#
# [211]	validation_0-rmse:0.374198	validation_1-rmse:0.378495
#
# [212]	validation_0-rmse:0.374093	validation_1-rmse:0.378388
#
# [213]	validation_0-rmse:0.373976	validation_1-rmse:0.37829
#
# [214]	validation_0-rmse:0.37386	validation_1-rmse:0.378181
#
# [215]	validation_0-rmse:0.373675	validation_1-rmse:0.378021
#
# [216]	validation_0-rmse:0.373638	validation_1-rmse:0.377991
#
# [217]	validation_0-rmse:0.373506	validation_1-rmse:0.377889
#
# [218]	validation_0-rmse:0.373321	validation_1-rmse:0.377748
#
# [219]	validation_0-rmse:0.373237	validation_1-rmse:0.37768
#
# [220]	validation_0-rmse:0.373079	validation_1-rmse:0.377513
#
# [221]	validation_0-rmse:0.372952	validation_1-rmse:0.37738
#
# [222]	validation_0-rmse:0.372938	validation_1-rmse:0.377363
#
# [223]	validation_0-rmse:0.372828	validation_1-rmse:0.377265
#
# [224]	validation_0-rmse:0.372807	validation_1-rmse:0.377238
#
# [225]	validation_0-rmse:0.372776	validation_1-rmse:0.3772
#
# [226]	validation_0-rmse:0.372681	validation_1-rmse:0.377108
#
# [227]	validation_0-rmse:0.372645	validation_1-rmse:0.377079
#
# [228]	validation_0-rmse:0.372531	validation_1-rmse:0.376982
#
# [229]	validation_0-rmse:0.372413	validation_1-rmse:0.376864
#
# [230]	validation_0-rmse:0.372283	validation_1-rmse:0.376742
#
# [231]	validation_0-rmse:0.372162	validation_1-rmse:0.376639
#
# [232]	validation_0-rmse:0.372125	validation_1-rmse:0.376618
#
# [233]	validation_0-rmse:0.37201	validation_1-rmse:0.376497
#
# [234]	validation_0-rmse:0.371926	validation_1-rmse:0.376432
#
# [235]	validation_0-rmse:0.371839	validation_1-rmse:0.376349
#
# [236]	validation_0-rmse:0.371689	validation_1-rmse:0.37623
#
# [237]	validation_0-rmse:0.371643	validation_1-rmse:0.376192
#
# [238]	validation_0-rmse:0.371575	validation_1-rmse:0.376126
#
# [239]	validation_0-rmse:0.371404	validation_1-rmse:0.375969
#
# [240]	validation_0-rmse:0.371376	validation_1-rmse:0.375954
#
# [241]	validation_0-rmse:0.371206	validation_1-rmse:0.375838
#
# [242]	validation_0-rmse:0.371157	validation_1-rmse:0.375797
#
# [243]	validation_0-rmse:0.371045	validation_1-rmse:0.375667
#
# [244]	validation_0-rmse:0.370888	validation_1-rmse:0.375543
#
# [245]	validation_0-rmse:0.370789	validation_1-rmse:0.375463
#
# [246]	validation_0-rmse:0.37071	validation_1-rmse:0.375397
#
# [247]	validation_0-rmse:0.370667	validation_1-rmse:0.375359
#
# [248]	validation_0-rmse:0.37058	validation_1-rmse:0.375291
#
# [249]	validation_0-rmse:0.370443	validation_1-rmse:0.375176
#
# [250]	validation_0-rmse:0.370427	validation_1-rmse:0.375165
#
# [251]	validation_0-rmse:0.370358	validation_1-rmse:0.375098
#
# [252]	validation_0-rmse:0.370253	validation_1-rmse:0.375011
#
# [253]	validation_0-rmse:0.370219	validation_1-rmse:0.374981
#
# [254]	validation_0-rmse:0.370112	validation_1-rmse:0.374856
#
# [255]	validation_0-rmse:0.37001	validation_1-rmse:0.374745
#
# [256]	validation_0-rmse:0.369972	validation_1-rmse:0.374711
#
# [257]	validation_0-rmse:0.369831	validation_1-rmse:0.374612
#
# [258]	validation_0-rmse:0.369766	validation_1-rmse:0.374542
#
# [259]	validation_0-rmse:0.369729	validation_1-rmse:0.3745
#
# [260]	validation_0-rmse:0.369675	validation_1-rmse:0.374443
#
# [261]	validation_0-rmse:0.369653	validation_1-rmse:0.374415
#
# [262]	validation_0-rmse:0.369552	validation_1-rmse:0.374317
#
# [263]	validation_0-rmse:0.369528	validation_1-rmse:0.374297
#
# [264]	validation_0-rmse:0.369431	validation_1-rmse:0.374224
#
# [265]	validation_0-rmse:0.36932	validation_1-rmse:0.374107
#
# [266]	validation_0-rmse:0.369242	validation_1-rmse:0.374036
#
# [267]	validation_0-rmse:0.36915	validation_1-rmse:0.37396
#
# [268]	validation_0-rmse:0.369097	validation_1-rmse:0.373919
#
# [269]	validation_0-rmse:0.368957	validation_1-rmse:0.373797
#
# [270]	validation_0-rmse:0.368941	validation_1-rmse:0.373777
#
# [271]	validation_0-rmse:0.368848	validation_1-rmse:0.373692
#
# [272]	validation_0-rmse:0.368758	validation_1-rmse:0.373626
#
# [273]	validation_0-rmse:0.368677	validation_1-rmse:0.373564
#
# [274]	validation_0-rmse:0.368588	validation_1-rmse:0.373464
#
# [275]	validation_0-rmse:0.368451	validation_1-rmse:0.373339
#
# [276]	validation_0-rmse:0.36838	validation_1-rmse:0.373293
#
# [277]	validation_0-rmse:0.368299	validation_1-rmse:0.373219
#
# [278]	validation_0-rmse:0.368174	validation_1-rmse:0.373105
#
# [279]	validation_0-rmse:0.368109	validation_1-rmse:0.373053
#
# [280]	validation_0-rmse:0.36805	validation_1-rmse:0.373005
#
# [281]	validation_0-rmse:0.368043	validation_1-rmse:0.373003
#
# [282]	validation_0-rmse:0.368008	validation_1-rmse:0.372977
#
# [283]	validation_0-rmse:0.367949	validation_1-rmse:0.372923
#
# [284]	validation_0-rmse:0.367875	validation_1-rmse:0.372837
#
# [285]	validation_0-rmse:0.367806	validation_1-rmse:0.372767
#
# [286]	validation_0-rmse:0.367795	validation_1-rmse:0.372764
#
# [287]	validation_0-rmse:0.367703	validation_1-rmse:0.372695
#
# [288]	validation_0-rmse:0.367629	validation_1-rmse:0.37263
#
# [289]	validation_0-rmse:0.367613	validation_1-rmse:0.37262
#
# [290]	validation_0-rmse:0.367501	validation_1-rmse:0.372527
#
# [291]	validation_0-rmse:0.367447	validation_1-rmse:0.372472
#
# [292]	validation_0-rmse:0.367432	validation_1-rmse:0.372452
#
# [293]	validation_0-rmse:0.367398	validation_1-rmse:0.372435
#
# [294]	validation_0-rmse:0.367334	validation_1-rmse:0.372388
#
# [295]	validation_0-rmse:0.367286	validation_1-rmse:0.372335
#
# [296]	validation_0-rmse:0.367169	validation_1-rmse:0.372237
#
# [297]	validation_0-rmse:0.367049	validation_1-rmse:0.372114
#
# [298]	validation_0-rmse:0.367026	validation_1-rmse:0.372084
#
# [299]	validation_0-rmse:0.366963	validation_1-rmse:0.372052
#
# [300]	validation_0-rmse:0.366934	validation_1-rmse:0.372028
#
# [301]	validation_0-rmse:0.366892	validation_1-rmse:0.372
#
# [302]	validation_0-rmse:0.366827	validation_1-rmse:0.371955
#
# [303]	validation_0-rmse:0.366745	validation_1-rmse:0.371864
#
# [304]	validation_0-rmse:0.36672	validation_1-rmse:0.371846
#
# [305]	validation_0-rmse:0.366685	validation_1-rmse:0.371804
#
# [306]	validation_0-rmse:0.366653	validation_1-rmse:0.371771
#
# [307]	validation_0-rmse:0.366578	validation_1-rmse:0.371702
#
# [308]	validation_0-rmse:0.366536	validation_1-rmse:0.371658
#
# [309]	validation_0-rmse:0.366526	validation_1-rmse:0.371648
#
# [310]	validation_0-rmse:0.366437	validation_1-rmse:0.371556
#
# [311]	validation_0-rmse:0.366355	validation_1-rmse:0.371495
#
# [312]	validation_0-rmse:0.366297	validation_1-rmse:0.37145
#
# [313]	validation_0-rmse:0.366222	validation_1-rmse:0.371373
#
# [314]	validation_0-rmse:0.366096	validation_1-rmse:0.371254
#
# [315]	validation_0-rmse:0.366019	validation_1-rmse:0.371196
#
# [316]	validation_0-rmse:0.365995	validation_1-rmse:0.371182
#
# [317]	validation_0-rmse:0.365968	validation_1-rmse:0.371163
#
# [318]	validation_0-rmse:0.365899	validation_1-rmse:0.371103
#
# [319]	validation_0-rmse:0.365814	validation_1-rmse:0.371048
#
# [320]	validation_0-rmse:0.365808	validation_1-rmse:0.371043
#
# [321]	validation_0-rmse:0.365754	validation_1-rmse:0.371007
#
# [322]	validation_0-rmse:0.365671	validation_1-rmse:0.37093
#
# [323]	validation_0-rmse:0.365602	validation_1-rmse:0.370859
#
# [324]	validation_0-rmse:0.365569	validation_1-rmse:0.370831
#
# [325]	validation_0-rmse:0.365479	validation_1-rmse:0.370754
#
# [326]	validation_0-rmse:0.365376	validation_1-rmse:0.370654
#
# [327]	validation_0-rmse:0.365355	validation_1-rmse:0.370637
#
# [328]	validation_0-rmse:0.365299	validation_1-rmse:0.370579
#
# [329]	validation_0-rmse:0.365232	validation_1-rmse:0.370522
#
# [330]	validation_0-rmse:0.365174	validation_1-rmse:0.37047
#
# [331]	validation_0-rmse:0.365062	validation_1-rmse:0.370375
#
# [332]	validation_0-rmse:0.365027	validation_1-rmse:0.370338
#
# [333]	validation_0-rmse:0.364966	validation_1-rmse:0.370279
#
# [334]	validation_0-rmse:0.364872	validation_1-rmse:0.37019
#
# [335]	validation_0-rmse:0.364824	validation_1-rmse:0.370161
#
# [336]	validation_0-rmse:0.364733	validation_1-rmse:0.370092
#
# [337]	validation_0-rmse:0.364714	validation_1-rmse:0.370071
#
# [338]	validation_0-rmse:0.364668	validation_1-rmse:0.370024
#
# [339]	validation_0-rmse:0.364638	validation_1-rmse:0.369994
#
# [340]	validation_0-rmse:0.364567	validation_1-rmse:0.369922
#
# [341]	validation_0-rmse:0.364543	validation_1-rmse:0.369907
#
# [342]	validation_0-rmse:0.364532	validation_1-rmse:0.369891
#
# [343]	validation_0-rmse:0.364461	validation_1-rmse:0.369831
#
# [344]	validation_0-rmse:0.364396	validation_1-rmse:0.369783
#
# [345]	validation_0-rmse:0.364377	validation_1-rmse:0.369761
#
# [346]	validation_0-rmse:0.364283	validation_1-rmse:0.369673
#
# [347]	validation_0-rmse:0.364257	validation_1-rmse:0.369641
#
# [348]	validation_0-rmse:0.364228	validation_1-rmse:0.36963
#
# [349]	validation_0-rmse:0.36419	validation_1-rmse:0.369584
#
# [350]	validation_0-rmse:0.364173	validation_1-rmse:0.36957
#
# [351]	validation_0-rmse:0.364098	validation_1-rmse:0.369504
#
# [352]	validation_0-rmse:0.364088	validation_1-rmse:0.369496
#
# [353]	validation_0-rmse:0.364031	validation_1-rmse:0.369447
#
# [354]	validation_0-rmse:0.364008	validation_1-rmse:0.369427
#
# [355]	validation_0-rmse:0.364002	validation_1-rmse:0.369426
#
# [356]	validation_0-rmse:0.363946	validation_1-rmse:0.369381
#
# [357]	validation_0-rmse:0.363903	validation_1-rmse:0.369346
#
# [358]	validation_0-rmse:0.363826	validation_1-rmse:0.369286
#
# [359]	validation_0-rmse:0.363821	validation_1-rmse:0.369283
#
# [360]	validation_0-rmse:0.363779	validation_1-rmse:0.369236
#
# [361]	validation_0-rmse:0.363751	validation_1-rmse:0.369218
#
# [362]	validation_0-rmse:0.363725	validation_1-rmse:0.369199
#
# [363]	validation_0-rmse:0.363669	validation_1-rmse:0.369148
#
# [364]	validation_0-rmse:0.363665	validation_1-rmse:0.369145
#
# [365]	validation_0-rmse:0.363576	validation_1-rmse:0.369064
#
# [366]	validation_0-rmse:0.36353	validation_1-rmse:0.36901
#
# [367]	validation_0-rmse:0.363452	validation_1-rmse:0.368942
#
# [368]	validation_0-rmse:0.363398	validation_1-rmse:0.368906
#
# [369]	validation_0-rmse:0.363387	validation_1-rmse:0.368894
#
# [370]	validation_0-rmse:0.363341	validation_1-rmse:0.368855
#
# [371]	validation_0-rmse:0.363257	validation_1-rmse:0.368777
#
# [372]	validation_0-rmse:0.363224	validation_1-rmse:0.368754
#
# [373]	validation_0-rmse:0.363176	validation_1-rmse:0.368714
#
# [374]	validation_0-rmse:0.363125	validation_1-rmse:0.368657
#
# [375]	validation_0-rmse:0.363071	validation_1-rmse:0.368602
#
# [376]	validation_0-rmse:0.363013	validation_1-rmse:0.368545
#
# [377]	validation_0-rmse:0.362972	validation_1-rmse:0.368501
#
# [378]	validation_0-rmse:0.362944	validation_1-rmse:0.36848
#
# [379]	validation_0-rmse:0.36292	validation_1-rmse:0.368465
#
# [380]	validation_0-rmse:0.362855	validation_1-rmse:0.36841
#
# [381]	validation_0-rmse:0.36279	validation_1-rmse:0.368342
#
# [382]	validation_0-rmse:0.36277	validation_1-rmse:0.368322
#
# [383]	validation_0-rmse:0.362746	validation_1-rmse:0.368289
#
# [384]	validation_0-rmse:0.36269	validation_1-rmse:0.368229
#
# [385]	validation_0-rmse:0.362659	validation_1-rmse:0.368212
#
# [386]	validation_0-rmse:0.362636	validation_1-rmse:0.368187
#
# [387]	validation_0-rmse:0.362591	validation_1-rmse:0.368138
#
# [388]	validation_0-rmse:0.362565	validation_1-rmse:0.368111
#
# [389]	validation_0-rmse:0.362491	validation_1-rmse:0.368052
#
# [390]	validation_0-rmse:0.362481	validation_1-rmse:0.368046
#
# [391]	validation_0-rmse:0.362445	validation_1-rmse:0.368029
#
# [392]	validation_0-rmse:0.362425	validation_1-rmse:0.368012
#
# [393]	validation_0-rmse:0.362405	validation_1-rmse:0.36799
#
# [394]	validation_0-rmse:0.362398	validation_1-rmse:0.367988
#
# [395]	validation_0-rmse:0.36235	validation_1-rmse:0.36794
#
# [396]	validation_0-rmse:0.36235	validation_1-rmse:0.36794
#
# [397]	validation_0-rmse:0.362343	validation_1-rmse:0.367929
#
# [398]	validation_0-rmse:0.362292	validation_1-rmse:0.367879
#
# [399]	validation_0-rmse:0.362254	validation_1-rmse:0.367843
#
# [400]	validation_0-rmse:0.362228	validation_1-rmse:0.367824
#
# [401]	validation_0-rmse:0.362176	validation_1-rmse:0.36778
#
# [402]	validation_0-rmse:0.362124	validation_1-rmse:0.367726
#
# [403]	validation_0-rmse:0.362112	validation_1-rmse:0.367712
#
# [404]	validation_0-rmse:0.362044	validation_1-rmse:0.367651
#
# [405]	validation_0-rmse:0.36203	validation_1-rmse:0.367639
#
# [406]	validation_0-rmse:0.361995	validation_1-rmse:0.367605
#
# [407]	validation_0-rmse:0.36195	validation_1-rmse:0.367571
#
# [408]	validation_0-rmse:0.361945	validation_1-rmse:0.367566
#
# [409]	validation_0-rmse:0.361912	validation_1-rmse:0.367531
#
# [410]	validation_0-rmse:0.361898	validation_1-rmse:0.367523
#
# [411]	validation_0-rmse:0.361854	validation_1-rmse:0.367485
#
# [412]	validation_0-rmse:0.36182	validation_1-rmse:0.367455
#
# [413]	validation_0-rmse:0.361792	validation_1-rmse:0.367432
#
# [414]	validation_0-rmse:0.361776	validation_1-rmse:0.367414
#
# [415]	validation_0-rmse:0.361767	validation_1-rmse:0.367404
#
# [416]	validation_0-rmse:0.361748	validation_1-rmse:0.36738
#
# [417]	validation_0-rmse:0.361702	validation_1-rmse:0.367342
#
# [418]	validation_0-rmse:0.361664	validation_1-rmse:0.367314
#
# [419]	validation_0-rmse:0.361649	validation_1-rmse:0.367306
#
# [420]	validation_0-rmse:0.361584	validation_1-rmse:0.367245
#
# [421]	validation_0-rmse:0.361574	validation_1-rmse:0.367232
#
# [422]	validation_0-rmse:0.361541	validation_1-rmse:0.367201
#
# [423]	validation_0-rmse:0.361521	validation_1-rmse:0.367173
#
# [424]	validation_0-rmse:0.361502	validation_1-rmse:0.367165
#
# [425]	validation_0-rmse:0.361489	validation_1-rmse:0.367159
#
# [426]	validation_0-rmse:0.361454	validation_1-rmse:0.367126
#
# [427]	validation_0-rmse:0.361425	validation_1-rmse:0.367101
#
# [428]	validation_0-rmse:0.361393	validation_1-rmse:0.36708
#
# [429]	validation_0-rmse:0.361344	validation_1-rmse:0.367033
#
# [430]	validation_0-rmse:0.361295	validation_1-rmse:0.366995
#
# [431]	validation_0-rmse:0.361263	validation_1-rmse:0.366962
#
# [432]	validation_0-rmse:0.361257	validation_1-rmse:0.366958
#
# [433]	validation_0-rmse:0.361199	validation_1-rmse:0.366905
#
# [434]	validation_0-rmse:0.361193	validation_1-rmse:0.366896
#
# [435]	validation_0-rmse:0.361168	validation_1-rmse:0.366868
#
# [436]	validation_0-rmse:0.361153	validation_1-rmse:0.366857
#
# [437]	validation_0-rmse:0.361111	validation_1-rmse:0.366819
#
# [438]	validation_0-rmse:0.361087	validation_1-rmse:0.366798
#
# [439]	validation_0-rmse:0.361049	validation_1-rmse:0.366753
#
# [440]	validation_0-rmse:0.360997	validation_1-rmse:0.366709
#
# [441]	validation_0-rmse:0.360981	validation_1-rmse:0.366691
#
# [442]	validation_0-rmse:0.360951	validation_1-rmse:0.366659
#
# [443]	validation_0-rmse:0.360943	validation_1-rmse:0.366656
#
# [444]	validation_0-rmse:0.360925	validation_1-rmse:0.366648
#
# [445]	validation_0-rmse:0.360899	validation_1-rmse:0.366626
#
# [446]	validation_0-rmse:0.360873	validation_1-rmse:0.366601
#
# [447]	validation_0-rmse:0.360873	validation_1-rmse:0.366601
#
# [448]	validation_0-rmse:0.360873	validation_1-rmse:0.366601
#
# [449]	validation_0-rmse:0.360869	validation_1-rmse:0.366594
#
# [450]	validation_0-rmse:0.360806	validation_1-rmse:0.366554
#
# [451]	validation_0-rmse:0.360801	validation_1-rmse:0.366548
#
# [452]	validation_0-rmse:0.360787	validation_1-rmse:0.366542
#
# [453]	validation_0-rmse:0.360759	validation_1-rmse:0.36652
#
# [454]	validation_0-rmse:0.360698	validation_1-rmse:0.366456
#
# [455]	validation_0-rmse:0.360641	validation_1-rmse:0.366405
#
# [456]	validation_0-rmse:0.360636	validation_1-rmse:0.366398
#
# [457]	validation_0-rmse:0.360636	validation_1-rmse:0.366398
#
# [458]	validation_0-rmse:0.360567	validation_1-rmse:0.36633
#
# [459]	validation_0-rmse:0.360552	validation_1-rmse:0.366324
#
# [460]	validation_0-rmse:0.360511	validation_1-rmse:0.366291
#
# [461]	validation_0-rmse:0.360504	validation_1-rmse:0.366284
#
# [462]	validation_0-rmse:0.360487	validation_1-rmse:0.366261
#
# [463]	validation_0-rmse:0.360472	validation_1-rmse:0.366253
#
# [464]	validation_0-rmse:0.36046	validation_1-rmse:0.366245
#
# [465]	validation_0-rmse:0.360382	validation_1-rmse:0.366177
#
# [466]	validation_0-rmse:0.360348	validation_1-rmse:0.366148
#
# [467]	validation_0-rmse:0.360348	validation_1-rmse:0.366148
#
# [468]	validation_0-rmse:0.360318	validation_1-rmse:0.36612
#
# [469]	validation_0-rmse:0.36028	validation_1-rmse:0.366101
#
# [470]	validation_0-rmse:0.360256	validation_1-rmse:0.366085
#
# [471]	validation_0-rmse:0.360217	validation_1-rmse:0.366059
#
# [472]	validation_0-rmse:0.360204	validation_1-rmse:0.366045
#
# [473]	validation_0-rmse:0.360191	validation_1-rmse:0.366037
#
# [474]	validation_0-rmse:0.36016	validation_1-rmse:0.366003
#
# [475]	validation_0-rmse:0.360135	validation_1-rmse:0.365984
#
# [476]	validation_0-rmse:0.360108	validation_1-rmse:0.365961
#
# [477]	validation_0-rmse:0.360097	validation_1-rmse:0.36595
#
# [478]	validation_0-rmse:0.360097	validation_1-rmse:0.36595
#
# [479]	validation_0-rmse:0.360045	validation_1-rmse:0.365907
#
# [480]	validation_0-rmse:0.360016	validation_1-rmse:0.365884
#
# [481]	validation_0-rmse:0.359988	validation_1-rmse:0.365865
#
# [482]	validation_0-rmse:0.359962	validation_1-rmse:0.365848
#
# [483]	validation_0-rmse:0.359925	validation_1-rmse:0.365807
#
# [484]	validation_0-rmse:0.359913	validation_1-rmse:0.365794
#
# [485]	validation_0-rmse:0.35989	validation_1-rmse:0.365775
#
# [486]	validation_0-rmse:0.359848	validation_1-rmse:0.365757
#
# [487]	validation_0-rmse:0.359843	validation_1-rmse:0.365749
#
# [488]	validation_0-rmse:0.359814	validation_1-rmse:0.365715
#
# [489]	validation_0-rmse:0.359794	validation_1-rmse:0.365691
#
# [490]	validation_0-rmse:0.359782	validation_1-rmse:0.365685
#
# [491]	validation_0-rmse:0.359754	validation_1-rmse:0.365662
#
# [492]	validation_0-rmse:0.359732	validation_1-rmse:0.365636
#
# [493]	validation_0-rmse:0.359723	validation_1-rmse:0.365631
#
# [494]	validation_0-rmse:0.35967	validation_1-rmse:0.365588
#
# [495]	validation_0-rmse:0.359628	validation_1-rmse:0.365545
#
# [496]	validation_0-rmse:0.359613	validation_1-rmse:0.365539
#
# [497]	validation_0-rmse:0.359589	validation_1-rmse:0.365512
#
# [498]	validation_0-rmse:0.359549	validation_1-rmse:0.365484
#
# [499]	validation_0-rmse:0.35953	validation_1-rmse:0.365469
#
# SCORE:
# 0.13356777736553868
# [0]	validation_0-rmse:1.03426	validation_1-rmse:1.03286
#
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
#
# [1]	validation_0-rmse:0.963337	validation_1-rmse:0.962738
#
# [2]	validation_0-rmse:0.899601	validation_1-rmse:0.89962
#
# [3]	validation_0-rmse:0.841971	validation_1-rmse:0.842639
#
# [4]	validation_0-rmse:0.790542	validation_1-rmse:0.791593
#
# [5]	validation_0-rmse:0.74545	validation_1-rmse:0.746683
#
# [6]	validation_0-rmse:0.705405	validation_1-rmse:0.707165
#
# [7]	validation_0-rmse:0.667725	validation_1-rmse:0.669851
#
# [8]	validation_0-rmse:0.634934	validation_1-rmse:0.637545
#
# [9]	validation_0-rmse:0.607242	validation_1-rmse:0.609921
#
# [10]	validation_0-rmse:0.580809	validation_1-rmse:0.583876
#
# [11]	validation_0-rmse:0.558535	validation_1-rmse:0.561762
#
# [12]	validation_0-rmse:0.538597	validation_1-rmse:0.541779
#
# [13]	validation_0-rmse:0.520002	validation_1-rmse:0.523413
#
# [14]	validation_0-rmse:0.504453	validation_1-rmse:0.507808
#
# [15]	validation_0-rmse:0.491278	validation_1-rmse:0.494576
#
# [16]	validation_0-rmse:0.479721	validation_1-rmse:0.483176
#
# [17]	validation_0-rmse:0.469429	validation_1-rmse:0.4731
#
# [18]	validation_0-rmse:0.459051	validation_1-rmse:0.462848
#
# [19]	validation_0-rmse:0.451848	validation_1-rmse:0.455415
#
# [20]	validation_0-rmse:0.445181	validation_1-rmse:0.448741
#
# [21]	validation_0-rmse:0.438691	validation_1-rmse:0.442413
#
# [22]	validation_0-rmse:0.433871	validation_1-rmse:0.437539
#
# [23]	validation_0-rmse:0.428363	validation_1-rmse:0.432167
#
# [24]	validation_0-rmse:0.42394	validation_1-rmse:0.427768
#
# [25]	validation_0-rmse:0.421055	validation_1-rmse:0.424786
#
# [26]	validation_0-rmse:0.418136	validation_1-rmse:0.421692
#
# [27]	validation_0-rmse:0.414987	validation_1-rmse:0.418562
#
# [28]	validation_0-rmse:0.412021	validation_1-rmse:0.415496
#
# [29]	validation_0-rmse:0.409834	validation_1-rmse:0.41331
#
# [30]	validation_0-rmse:0.406751	validation_1-rmse:0.410115
#
# [31]	validation_0-rmse:0.404456	validation_1-rmse:0.407795
#
# [32]	validation_0-rmse:0.402672	validation_1-rmse:0.406036
#
# [33]	validation_0-rmse:0.401042	validation_1-rmse:0.404318
#
# [34]	validation_0-rmse:0.399682	validation_1-rmse:0.402855
#
# [35]	validation_0-rmse:0.39798	validation_1-rmse:0.401111
#
# [36]	validation_0-rmse:0.397512	validation_1-rmse:0.400586
#
# [37]	validation_0-rmse:0.396699	validation_1-rmse:0.399628
#
# [38]	validation_0-rmse:0.396008	validation_1-rmse:0.398868
#
# [39]	validation_0-rmse:0.395018	validation_1-rmse:0.397854
#
# [40]	validation_0-rmse:0.393596	validation_1-rmse:0.396373
#
# [41]	validation_0-rmse:0.393253	validation_1-rmse:0.395971
#
# [42]	validation_0-rmse:0.392616	validation_1-rmse:0.395296
#
# [43]	validation_0-rmse:0.391907	validation_1-rmse:0.394631
#
# [44]	validation_0-rmse:0.39161	validation_1-rmse:0.394334
#
# [45]	validation_0-rmse:0.390761	validation_1-rmse:0.393498
#
# [46]	validation_0-rmse:0.390085	validation_1-rmse:0.392884
#
# [47]	validation_0-rmse:0.389814	validation_1-rmse:0.392687
#
# [48]	validation_0-rmse:0.38955	validation_1-rmse:0.392355
#
# [49]	validation_0-rmse:0.389097	validation_1-rmse:0.391825
#
# [50]	validation_0-rmse:0.388493	validation_1-rmse:0.391273
#
# [51]	validation_0-rmse:0.387966	validation_1-rmse:0.390709
#
# [52]	validation_0-rmse:0.387963	validation_1-rmse:0.390705
#
# [53]	validation_0-rmse:0.387961	validation_1-rmse:0.390702
#
# [54]	validation_0-rmse:0.387295	validation_1-rmse:0.389917
#
# [55]	validation_0-rmse:0.387295	validation_1-rmse:0.389917
#
# [56]	validation_0-rmse:0.38696	validation_1-rmse:0.389501
#
# [57]	validation_0-rmse:0.386476	validation_1-rmse:0.38907
#
# [58]	validation_0-rmse:0.386474	validation_1-rmse:0.389066
#
# [59]	validation_0-rmse:0.386471	validation_1-rmse:0.38906
#
# [60]	validation_0-rmse:0.38603	validation_1-rmse:0.388697
#
# [61]	validation_0-rmse:0.38603	validation_1-rmse:0.388696
#
# [62]	validation_0-rmse:0.386028	validation_1-rmse:0.388689
#
# [63]	validation_0-rmse:0.386027	validation_1-rmse:0.388688
#
# [64]	validation_0-rmse:0.386027	validation_1-rmse:0.388688
#
# [65]	validation_0-rmse:0.386027	validation_1-rmse:0.388688
#
# [66]	validation_0-rmse:0.386026	validation_1-rmse:0.388685
#
# [67]	validation_0-rmse:0.386026	validation_1-rmse:0.388685
#
# [68]	validation_0-rmse:0.385638	validation_1-rmse:0.388316
#
# [69]	validation_0-rmse:0.385639	validation_1-rmse:0.388315
#
# [70]	validation_0-rmse:0.385639	validation_1-rmse:0.388315
#
# [71]	validation_0-rmse:0.385638	validation_1-rmse:0.388316
#
# [72]	validation_0-rmse:0.385639	validation_1-rmse:0.388318
#
# [73]	validation_0-rmse:0.385639	validation_1-rmse:0.388318
#
# [74]	validation_0-rmse:0.385639	validation_1-rmse:0.388318
#
# [75]	validation_0-rmse:0.385639	validation_1-rmse:0.388318
#
# [76]	validation_0-rmse:0.385639	validation_1-rmse:0.388318
#
# [77]	validation_0-rmse:0.385637	validation_1-rmse:0.388314
#
# [78]	validation_0-rmse:0.385637	validation_1-rmse:0.388314
#
# [79]	validation_0-rmse:0.385637	validation_1-rmse:0.388313
#
# [80]	validation_0-rmse:0.385637	validation_1-rmse:0.388313
#
# [81]	validation_0-rmse:0.385125	validation_1-rmse:0.387832
#
# [82]	validation_0-rmse:0.385125	validation_1-rmse:0.387832
#
# [83]	validation_0-rmse:0.385125	validation_1-rmse:0.387833
#
# [84]	validation_0-rmse:0.384674	validation_1-rmse:0.387328
#
# [85]	validation_0-rmse:0.384401	validation_1-rmse:0.387076
#
# [86]	validation_0-rmse:0.384401	validation_1-rmse:0.387079
#
# [87]	validation_0-rmse:0.384401	validation_1-rmse:0.387079
#
# [88]	validation_0-rmse:0.384401	validation_1-rmse:0.387079
#
# [89]	validation_0-rmse:0.383956	validation_1-rmse:0.386634
#
# [90]	validation_0-rmse:0.383955	validation_1-rmse:0.38663
#
# [91]	validation_0-rmse:0.383955	validation_1-rmse:0.38663
#
# [92]	validation_0-rmse:0.383954	validation_1-rmse:0.386625
#
# [93]	validation_0-rmse:0.383954	validation_1-rmse:0.386625
#
# [94]	validation_0-rmse:0.383954	validation_1-rmse:0.386625
#
# [95]	validation_0-rmse:0.383592	validation_1-rmse:0.386276
#
# [96]	validation_0-rmse:0.383592	validation_1-rmse:0.386276
#
# [97]	validation_0-rmse:0.383592	validation_1-rmse:0.386276
#
# [98]	validation_0-rmse:0.383591	validation_1-rmse:0.386279
#
# [99]	validation_0-rmse:0.383593	validation_1-rmse:0.386281
#
# [100]	validation_0-rmse:0.383593	validation_1-rmse:0.386281
#
# [101]	validation_0-rmse:0.383592	validation_1-rmse:0.386281
#
# [102]	validation_0-rmse:0.383592	validation_1-rmse:0.386281
#
# [103]	validation_0-rmse:0.382977	validation_1-rmse:0.385631
#
# [104]	validation_0-rmse:0.382977	validation_1-rmse:0.385631
#
# [105]	validation_0-rmse:0.382821	validation_1-rmse:0.385471
#
# [106]	validation_0-rmse:0.382821	validation_1-rmse:0.385473
#
# [107]	validation_0-rmse:0.382821	validation_1-rmse:0.385472
#
# [108]	validation_0-rmse:0.38282	validation_1-rmse:0.385471
#
# [109]	validation_0-rmse:0.382379	validation_1-rmse:0.385108
#
# [110]	validation_0-rmse:0.382379	validation_1-rmse:0.385108
#
# [111]	validation_0-rmse:0.382379	validation_1-rmse:0.385108
#
# [112]	validation_0-rmse:0.381615	validation_1-rmse:0.384334
#
# [113]	validation_0-rmse:0.381615	validation_1-rmse:0.384334
#
# [114]	validation_0-rmse:0.381615	validation_1-rmse:0.384334
#
# [115]	validation_0-rmse:0.381316	validation_1-rmse:0.383979
#
# [116]	validation_0-rmse:0.381316	validation_1-rmse:0.383979
#
# [117]	validation_0-rmse:0.381315	validation_1-rmse:0.383978
#
# [118]	validation_0-rmse:0.381315	validation_1-rmse:0.383978
#
# [119]	validation_0-rmse:0.380934	validation_1-rmse:0.38355
#
# [120]	validation_0-rmse:0.380934	validation_1-rmse:0.38355
#
# [121]	validation_0-rmse:0.380934	validation_1-rmse:0.38355
#
# [122]	validation_0-rmse:0.380934	validation_1-rmse:0.383548
#
# [123]	validation_0-rmse:0.380934	validation_1-rmse:0.383548
#
# [124]	validation_0-rmse:0.380934	validation_1-rmse:0.383548
#
# [125]	validation_0-rmse:0.380934	validation_1-rmse:0.383548
#
# [126]	validation_0-rmse:0.380934	validation_1-rmse:0.383548
#
# [127]	validation_0-rmse:0.380934	validation_1-rmse:0.383548
#
# [128]	validation_0-rmse:0.380934	validation_1-rmse:0.383548
#
# [129]	validation_0-rmse:0.380934	validation_1-rmse:0.383548
#
# [130]	validation_0-rmse:0.380934	validation_1-rmse:0.383548
#
# [131]	validation_0-rmse:0.380934	validation_1-rmse:0.383548
#
# [132]	validation_0-rmse:0.380934	validation_1-rmse:0.383549
#
# Stopping. Best iteration:
# [122]	validation_0-rmse:0.380934	validation_1-rmse:0.383548
#
#
# SCORE:
# 0.14710947875389357
# [0]	validation_0-rmse:1.04866	validation_1-rmse:1.04728
#
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
#
# [1]	validation_0-rmse:0.989411	validation_1-rmse:0.988571
#
# [2]	validation_0-rmse:0.934973	validation_1-rmse:0.934462
#
# [3]	validation_0-rmse:0.885605	validation_1-rmse:0.885501
#
# [4]	validation_0-rmse:0.839832	validation_1-rmse:0.840396
#
# [5]	validation_0-rmse:0.798361	validation_1-rmse:0.799325
#
# [6]	validation_0-rmse:0.760589	validation_1-rmse:0.761827
#
# [7]	validation_0-rmse:0.724928	validation_1-rmse:0.726425
#
# [8]	validation_0-rmse:0.694204	validation_1-rmse:0.695843
#
# [9]	validation_0-rmse:0.665592	validation_1-rmse:0.667502
#
# [10]	validation_0-rmse:0.640494	validation_1-rmse:0.642404
#
# [11]	validation_0-rmse:0.615119	validation_1-rmse:0.617501
#
# [12]	validation_0-rmse:0.593293	validation_1-rmse:0.595766
#
# [13]	validation_0-rmse:0.573189	validation_1-rmse:0.575922
#
# [14]	validation_0-rmse:0.555634	validation_1-rmse:0.558509
#
# [15]	validation_0-rmse:0.538665	validation_1-rmse:0.541783
#
# [16]	validation_0-rmse:0.524011	validation_1-rmse:0.527108
#
# [17]	validation_0-rmse:0.510704	validation_1-rmse:0.514006
#
# [18]	validation_0-rmse:0.497996	validation_1-rmse:0.501412
#
# [19]	validation_0-rmse:0.488306	validation_1-rmse:0.491511
#
# [20]	validation_0-rmse:0.478684	validation_1-rmse:0.481871
#
# [21]	validation_0-rmse:0.469588	validation_1-rmse:0.472942
#
# [22]	validation_0-rmse:0.462618	validation_1-rmse:0.465805
#
# [23]	validation_0-rmse:0.455198	validation_1-rmse:0.458547
#
# [24]	validation_0-rmse:0.448994	validation_1-rmse:0.45247
#
# [25]	validation_0-rmse:0.443046	validation_1-rmse:0.446625
#
# [26]	validation_0-rmse:0.43826	validation_1-rmse:0.441739
#
# [27]	validation_0-rmse:0.433739	validation_1-rmse:0.437346
#
# [28]	validation_0-rmse:0.429722	validation_1-rmse:0.433452
#
# [29]	validation_0-rmse:0.425786	validation_1-rmse:0.42939
#
# [30]	validation_0-rmse:0.421758	validation_1-rmse:0.425366
#
# [31]	validation_0-rmse:0.418727	validation_1-rmse:0.422418
#
# [32]	validation_0-rmse:0.415695	validation_1-rmse:0.419342
#
# [33]	validation_0-rmse:0.412891	validation_1-rmse:0.416612
#
# [34]	validation_0-rmse:0.410728	validation_1-rmse:0.414311
#
# [35]	validation_0-rmse:0.40873	validation_1-rmse:0.412219
#
# [36]	validation_0-rmse:0.406979	validation_1-rmse:0.41038
#
# [37]	validation_0-rmse:0.405415	validation_1-rmse:0.408781
#
# [38]	validation_0-rmse:0.40382	validation_1-rmse:0.407288
#
# ...
# [224]	validation_0-rmse:0.37103	validation_1-rmse:0.375278
#
# [225]	validation_0-rmse:0.371029	validation_1-rmse:0.375278
#
# [226]	validation_0-rmse:0.371029	validation_1-rmse:0.375278
#
# [227]	validation_0-rmse:0.371029	validation_1-rmse:0.375278
#
# [228]	validation_0-rmse:0.371029	validation_1-rmse:0.375278
#
# [229]	validation_0-rmse:0.371029	validation_1-rmse:0.375278
#
# [230]	validation_0-rmse:0.370874	validation_1-rmse:0.375113
#
# [231]	validation_0-rmse:0.370874	validation_1-rmse:0.375113
#
# [232]	validation_0-rmse:0.370874	validation_1-rmse:0.375113
#
# [233]	validation_0-rmse:0.370773	validation_1-rmse:0.375033
#
# [234]	validation_0-rmse:0.370703	validation_1-rmse:0.374957
#
# [235]	validation_0-rmse:0.370703	validation_1-rmse:0.374957
#
# [236]	validation_0-rmse:0.370616	validation_1-rmse:0.37489
#
# [237]	validation_0-rmse:0.370616	validation_1-rmse:0.37489
#
# [238]	validation_0-rmse:0.370616	validation_1-rmse:0.37489
#
# [239]	validation_0-rmse:0.370616	validation_1-rmse:0.37489
#
# [240]	validation_0-rmse:0.370505	validation_1-rmse:0.374771
#
# [241]	validation_0-rmse:0.370505	validation_1-rmse:0.374771
#
# [242]	validation_0-rmse:0.370505	validation_1-rmse:0.374771
#
# [243]	validation_0-rmse:0.370411	validation_1-rmse:0.374668
#
# [244]	validation_0-rmse:0.370411	validation_1-rmse:0.374668
#
# [245]	validation_0-rmse:0.370411	validation_1-rmse:0.374668
#
# [246]	validation_0-rmse:0.370411	validation_1-rmse:0.374668
#
# [247]	validation_0-rmse:0.370411	validation_1-rmse:0.374668
#
# [248]	validation_0-rmse:0.370346	validation_1-rmse:0.374623
#
# [249]	validation_0-rmse:0.370346	validation_1-rmse:0.374623
#
# [250]	validation_0-rmse:0.370272	validation_1-rmse:0.374531
#
# [251]	validation_0-rmse:0.370272	validation_1-rmse:0.374531
#
# [252]	validation_0-rmse:0.370272	validation_1-rmse:0.374531
#
# [253]	validation_0-rmse:0.370066	validation_1-rmse:0.374304
#
# [254]	validation_0-rmse:0.370066	validation_1-rmse:0.374304
#
# [255]	validation_0-rmse:0.36997	validation_1-rmse:0.374204
#
# [256]	validation_0-rmse:0.36997	validation_1-rmse:0.374204
#
# [257]	validation_0-rmse:0.36997	validation_1-rmse:0.374204
#
# [258]	validation_0-rmse:0.36997	validation_1-rmse:0.374204
#
# [259]	validation_0-rmse:0.36997	validation_1-rmse:0.374204
#
# [260]	validation_0-rmse:0.369877	validation_1-rmse:0.374096
#
# [261]	validation_0-rmse:0.369877	validation_1-rmse:0.374096
#
# [262]	validation_0-rmse:0.369877	validation_1-rmse:0.374096
#
# [263]	validation_0-rmse:0.369877	validation_1-rmse:0.374096
#
# [264]	validation_0-rmse:0.369877	validation_1-rmse:0.374096
#
# [265]	validation_0-rmse:0.369741	validation_1-rmse:0.37398
#
# [266]	validation_0-rmse:0.369649	validation_1-rmse:0.373903
#
# [267]	validation_0-rmse:0.369649	validation_1-rmse:0.373903
#
# [268]	validation_0-rmse:0.36965	validation_1-rmse:0.373903
#
# [269]	validation_0-rmse:0.36965	validation_1-rmse:0.373903
#
# [270]	validation_0-rmse:0.36965	validation_1-rmse:0.373903
#
# [271]	validation_0-rmse:0.369572	validation_1-rmse:0.373851
#
# [272]	validation_0-rmse:0.369509	validation_1-rmse:0.373787
#
# [273]	validation_0-rmse:0.369509	validation_1-rmse:0.373787
#
# [274]	validation_0-rmse:0.369509	validation_1-rmse:0.373787
#
# [275]	validation_0-rmse:0.36941	validation_1-rmse:0.373681
#
# [276]	validation_0-rmse:0.36941	validation_1-rmse:0.373681
#
# [277]	validation_0-rmse:0.36941	validation_1-rmse:0.373681
#
# [278]	validation_0-rmse:0.36941	validation_1-rmse:0.373681
#
# [279]	validation_0-rmse:0.36941	validation_1-rmse:0.373681
#
# [280]	validation_0-rmse:0.369342	validation_1-rmse:0.37363
#
# [281]	validation_0-rmse:0.369342	validation_1-rmse:0.37363
#
# [282]	validation_0-rmse:0.369342	validation_1-rmse:0.37363
#
# [283]	validation_0-rmse:0.369342	validation_1-rmse:0.37363
#
# [284]	validation_0-rmse:0.369343	validation_1-rmse:0.37363
#
# [285]	validation_0-rmse:0.369343	validation_1-rmse:0.37363
#
# [286]	validation_0-rmse:0.369343	validation_1-rmse:0.37363
#
# [287]	validation_0-rmse:0.369266	validation_1-rmse:0.373558
#
# [288]	validation_0-rmse:0.369201	validation_1-rmse:0.373482
#
# [289]	validation_0-rmse:0.369201	validation_1-rmse:0.373482
#
# [290]	validation_0-rmse:0.369201	validation_1-rmse:0.373482
#
# [291]	validation_0-rmse:0.369201	validation_1-rmse:0.373482
#
# [292]	validation_0-rmse:0.369201	validation_1-rmse:0.373482
#
# [293]	validation_0-rmse:0.369201	validation_1-rmse:0.373482
#
# [294]	validation_0-rmse:0.369132	validation_1-rmse:0.373419
#
# [295]	validation_0-rmse:0.369132	validation_1-rmse:0.373419
#
# [296]	validation_0-rmse:0.369133	validation_1-rmse:0.373419
#
# [297]	validation_0-rmse:0.369133	validation_1-rmse:0.373419
#
# [298]	validation_0-rmse:0.369049	validation_1-rmse:0.373329
#
# [299]	validation_0-rmse:0.369049	validation_1-rmse:0.373329
#
# SCORE:
# 0.13937485081856896
# [0]	validation_0-rmse:1.0497	validation_1-rmse:1.04792
#
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
#
# [1]	validation_0-rmse:0.991008	validation_1-rmse:0.989687
#
# [2]	validation_0-rmse:0.937895	validation_1-rmse:0.936734
#
# [3]	validation_0-rmse:0.888791	validation_1-rmse:0.88812
#
# [4]	validation_0-rmse:0.844596	validation_1-rmse:0.844146
#
# [5]	validation_0-rmse:0.803722	validation_1-rmse:0.803464
#
# [6]	validation_0-rmse:0.767944	validation_1-rmse:0.767738
#
# [7]	validation_0-rmse:0.732163	validation_1-rmse:0.732185
#
# [8]	validation_0-rmse:0.700499	validation_1-rmse:0.700748
#
# [9]	validation_0-rmse:0.674589	validation_1-rmse:0.674769
#
# [10]	validation_0-rmse:0.650292	validation_1-rmse:0.650345
#
# [11]	validation_0-rmse:0.626434	validation_1-rmse:0.626936
#
# [12]	validation_0-rmse:0.604551	validation_1-rmse:0.605239
#
# [13]	validation_0-rmse:0.586462	validation_1-rmse:0.586934
#
# [14]	validation_0-rmse:0.56931	validation_1-rmse:0.569932
#
# [15]	validation_0-rmse:0.554227	validation_1-rmse:0.555156
#
# [16]	validation_0-rmse:0.539971	validation_1-rmse:0.5411
#
# [17]	validation_0-rmse:0.527869	validation_1-rmse:0.528875
#
# [18]	validation_0-rmse:0.516022	validation_1-rmse:0.517113
#
# [19]	validation_0-rmse:0.507112	validation_1-rmse:0.508109
#
# [20]	validation_0-rmse:0.498929	validation_1-rmse:0.499872
#
# [21]	validation_0-rmse:0.489811	validation_1-rmse:0.491092
#
# [22]	validation_0-rmse:0.482095	validation_1-rmse:0.483547
#
# [23]	validation_0-rmse:0.474936	validation_1-rmse:0.476443
#
# [24]	validation_0-rmse:0.469337	validation_1-rmse:0.470999
#
# [25]	validation_0-rmse:0.464348	validation_1-rmse:0.466174
#
# [26]	validation_0-rmse:0.459025	validation_1-rmse:0.460742
#
# [27]	validation_0-rmse:0.45439	validation_1-rmse:0.45608
#
# [28]	validation_0-rmse:0.449791	validation_1-rmse:0.45149
#
# [29]	validation_0-rmse:0.445815	validation_1-rmse:0.447397
#
# [30]	validation_0-rmse:0.442681	validation_1-rmse:0.444366
#
# [31]	validation_0-rmse:0.439069	validation_1-rmse:0.440714
#
# [32]	validation_0-rmse:0.436212	validation_1-rmse:0.43771
#
# [33]	validation_0-rmse:0.433423	validation_1-rmse:0.434905
#
# [34]	validation_0-rmse:0.431364	validation_1-rmse:0.432802
#
# [35]	validation_0-rmse:0.428694	validation_1-rmse:0.430127
#
# [36]	validation_0-rmse:0.426975	validation_1-rmse:0.428254
#
# [37]	validation_0-rmse:0.425007	validation_1-rmse:0.426235
#
# [38]	validation_0-rmse:0.423582	validation_1-rmse:0.424787
#
# [39]	validation_0-rmse:0.421172	validation_1-rmse:0.422325
#
# [40]	validation_0-rmse:0.419809	validation_1-rmse:0.42082
#
# [41]	validation_0-rmse:0.418711	validation_1-rmse:0.41966
#
# [42]	validation_0-rmse:0.417779	validation_1-rmse:0.418634
#
# [43]	validation_0-rmse:0.416914	validation_1-rmse:0.417765
#
# [44]	validation_0-rmse:0.415498	validation_1-rmse:0.41654
#
# [45]	validation_0-rmse:0.413852	validation_1-rmse:0.414967
#
# [46]	validation_0-rmse:0.413108	validation_1-rmse:0.414153
#
# [47]	validation_0-rmse:0.4122	validation_1-rmse:0.413199
#
# [48]	validation_0-rmse:0.410921	validation_1-rmse:0.411902
#
# [49]	validation_0-rmse:0.410289	validation_1-rmse:0.411238
#
# [50]	validation_0-rmse:0.409355	validation_1-rmse:0.410394
#
# [51]	validation_0-rmse:0.408813	validation_1-rmse:0.409826
#
# [52]	validation_0-rmse:0.407822	validation_1-rmse:0.408858
#
# [53]	validation_0-rmse:0.407256	validation_1-rmse:0.408335
#
# [54]	validation_0-rmse:0.406652	validation_1-rmse:0.407703
#
# [55]	validation_0-rmse:0.406157	validation_1-rmse:0.407262
#
# [56]	validation_0-rmse:0.405819	validation_1-rmse:0.406924
#
# [57]	validation_0-rmse:0.405512	validation_1-rmse:0.406595
#
# [58]	validation_0-rmse:0.405252	validation_1-rmse:0.406301
#
# [59]	validation_0-rmse:0.404961	validation_1-rmse:0.405961
#
# [60]	validation_0-rmse:0.404468	validation_1-rmse:0.40554
#
# [61]	validation_0-rmse:0.404089	validation_1-rmse:0.405194
#
# [62]	validation_0-rmse:0.403813	validation_1-rmse:0.404914
#
# [63]	validation_0-rmse:0.403426	validation_1-rmse:0.404544
#
# [64]	validation_0-rmse:0.402979	validation_1-rmse:0.404034
#
# [65]	validation_0-rmse:0.402825	validation_1-rmse:0.403888
#
# [66]	validation_0-rmse:0.402421	validation_1-rmse:0.403535
#
# [67]	validation_0-rmse:0.40203	validation_1-rmse:0.403182
#
# [68]	validation_0-rmse:0.401861	validation_1-rmse:0.402984
#
# [69]	validation_0-rmse:0.401355	validation_1-rmse:0.402416
#
# [70]	validation_0-rmse:0.400884	validation_1-rmse:0.401972
#
# [71]	validation_0-rmse:0.400694	validation_1-rmse:0.401775
#
# [72]	validation_0-rmse:0.400619	validation_1-rmse:0.401711
#
# [73]	validation_0-rmse:0.400416	validation_1-rmse:0.401477
#
# [74]	validation_0-rmse:0.400321	validation_1-rmse:0.401385
#
# [75]	validation_0-rmse:0.400261	validation_1-rmse:0.401324
#
# [76]	validation_0-rmse:0.399982	validation_1-rmse:0.401063
#
# [77]	validation_0-rmse:0.399935	validation_1-rmse:0.401008
#
# [78]	validation_0-rmse:0.399337	validation_1-rmse:0.400451
#
# [79]	validation_0-rmse:0.399066	validation_1-rmse:0.400154
#
# [80]	validation_0-rmse:0.398974	validation_1-rmse:0.400033
#
# [81]	validation_0-rmse:0.398725	validation_1-rmse:0.399759
#
# [82]	validation_0-rmse:0.398674	validation_1-rmse:0.399714
#
# [83]	validation_0-rmse:0.398674	validation_1-rmse:0.399714
#
# [84]	validation_0-rmse:0.398356	validation_1-rmse:0.399456
#
# [85]	validation_0-rmse:0.398356	validation_1-rmse:0.399456
#
# [86]	validation_0-rmse:0.398235	validation_1-rmse:0.399351
#
# [87]	validation_0-rmse:0.398201	validation_1-rmse:0.39932
#
# [88]	validation_0-rmse:0.397983	validation_1-rmse:0.399145
#
# [89]	validation_0-rmse:0.397983	validation_1-rmse:0.399145
#
# [90]	validation_0-rmse:0.397891	validation_1-rmse:0.399035
#
# [91]	validation_0-rmse:0.397891	validation_1-rmse:0.399035
#
# [92]	validation_0-rmse:0.397802	validation_1-rmse:0.39892
#
# [93]	validation_0-rmse:0.39759	validation_1-rmse:0.398696
#
# [94]	validation_0-rmse:0.397417	validation_1-rmse:0.398484
#
# [95]	validation_0-rmse:0.39719	validation_1-rmse:0.398253
#
# [96]	validation_0-rmse:0.396957	validation_1-rmse:0.398011
#
# [97]	validation_0-rmse:0.396957	validation_1-rmse:0.398011
#
# [98]	validation_0-rmse:0.396898	validation_1-rmse:0.397967
#
# [99]	validation_0-rmse:0.396898	validation_1-rmse:0.397967
#
# [100]	validation_0-rmse:0.396726	validation_1-rmse:0.397771
#
# [101]	validation_0-rmse:0.396726	validation_1-rmse:0.397771
#
# [102]	validation_0-rmse:0.396574	validation_1-rmse:0.397635
#
# [103]	validation_0-rmse:0.396574	validation_1-rmse:0.397635
#
# [104]	validation_0-rmse:0.396337	validation_1-rmse:0.397396
#
# [105]	validation_0-rmse:0.396337	validation_1-rmse:0.397395
#
# [106]	validation_0-rmse:0.39627	validation_1-rmse:0.39734
#
# [107]	validation_0-rmse:0.39601	validation_1-rmse:0.397054
#
# [108]	validation_0-rmse:0.395732	validation_1-rmse:0.396832
#
# [109]	validation_0-rmse:0.395585	validation_1-rmse:0.396721
#
# [110]	validation_0-rmse:0.395349	validation_1-rmse:0.396466
#
# [111]	validation_0-rmse:0.395349	validation_1-rmse:0.396466
#
# [112]	validation_0-rmse:0.395348	validation_1-rmse:0.396465
#
# [113]	validation_0-rmse:0.395348	validation_1-rmse:0.396465
#
# [114]	validation_0-rmse:0.395348	validation_1-rmse:0.396465
#
# [115]	validation_0-rmse:0.395348	validation_1-rmse:0.396465
#
# [116]	validation_0-rmse:0.395044	validation_1-rmse:0.396148
#
# [117]	validation_0-rmse:0.395044	validation_1-rmse:0.396148
#
# [118]	validation_0-rmse:0.395044	validation_1-rmse:0.396148
#
# [119]	validation_0-rmse:0.394829	validation_1-rmse:0.395974
#
# [120]	validation_0-rmse:0.394724	validation_1-rmse:0.395862
#
# [121]	validation_0-rmse:0.394724	validation_1-rmse:0.395862
#
# [122]	validation_0-rmse:0.394724	validation_1-rmse:0.395862
#
# [123]	validation_0-rmse:0.394724	validation_1-rmse:0.395862
#
# [124]	validation_0-rmse:0.394724	validation_1-rmse:0.395862
#
# [125]	validation_0-rmse:0.394503	validation_1-rmse:0.395606
#
# [126]	validation_0-rmse:0.394502	validation_1-rmse:0.395606
#
# [127]	validation_0-rmse:0.394423	validation_1-rmse:0.395556
#
# [128]	validation_0-rmse:0.394423	validation_1-rmse:0.395556
#
# [129]	validation_0-rmse:0.394423	validation_1-rmse:0.395556
#
# [130]	validation_0-rmse:0.394423	validation_1-rmse:0.395556
#
# [131]	validation_0-rmse:0.394292	validation_1-rmse:0.3954
#
# [132]	validation_0-rmse:0.394292	validation_1-rmse:0.3954
#
# [133]	validation_0-rmse:0.394196	validation_1-rmse:0.395326
#
# [134]	validation_0-rmse:0.394003	validation_1-rmse:0.395144
#
# [135]	validation_0-rmse:0.394003	validation_1-rmse:0.395144
#
# [136]	validation_0-rmse:0.394003	validation_1-rmse:0.395144
#
# [137]	validation_0-rmse:0.394003	validation_1-rmse:0.395144
#
# [138]	validation_0-rmse:0.394003	validation_1-rmse:0.395144
#
# [139]	validation_0-rmse:0.393878	validation_1-rmse:0.394991
#
# [140]	validation_0-rmse:0.393878	validation_1-rmse:0.394991
#
# [141]	validation_0-rmse:0.393878	validation_1-rmse:0.394991
#
# [142]	validation_0-rmse:0.393752	validation_1-rmse:0.394866
#
# [143]	validation_0-rmse:0.393752	validation_1-rmse:0.394866
#
# [144]	validation_0-rmse:0.393542	validation_1-rmse:0.394749
#
# [145]	validation_0-rmse:0.393542	validation_1-rmse:0.394749
#
# [146]	validation_0-rmse:0.393542	validation_1-rmse:0.394749
#
# [147]	validation_0-rmse:0.393542	validation_1-rmse:0.394749
#
# [148]	validation_0-rmse:0.39331	validation_1-rmse:0.3945
#
# [149]	validation_0-rmse:0.39331	validation_1-rmse:0.3945
#
# [150]	validation_0-rmse:0.39331	validation_1-rmse:0.3945
#
# [151]	validation_0-rmse:0.39331	validation_1-rmse:0.3945
#
# [152]	validation_0-rmse:0.393177	validation_1-rmse:0.394337
#
# [153]	validation_0-rmse:0.393177	validation_1-rmse:0.394337
#
# [154]	validation_0-rmse:0.393177	validation_1-rmse:0.394337
#
# [155]	validation_0-rmse:0.393177	validation_1-rmse:0.394337
#
# [156]	validation_0-rmse:0.393177	validation_1-rmse:0.394337
#
# [157]	validation_0-rmse:0.393177	validation_1-rmse:0.394337
#
# [158]	validation_0-rmse:0.393177	validation_1-rmse:0.394337
#
# [159]	validation_0-rmse:0.393177	validation_1-rmse:0.394337
#
# [160]	validation_0-rmse:0.393073	validation_1-rmse:0.394256
#
# [161]	validation_0-rmse:0.392881	validation_1-rmse:0.394112
#
# [162]	validation_0-rmse:0.39276	validation_1-rmse:0.394011
#
# [163]	validation_0-rmse:0.39276	validation_1-rmse:0.394011
#
# [164]	validation_0-rmse:0.39276	validation_1-rmse:0.394011
#
# [165]	validation_0-rmse:0.39276	validation_1-rmse:0.394011
#
# [166]	validation_0-rmse:0.39276	validation_1-rmse:0.394011
#
# [167]	validation_0-rmse:0.39276	validation_1-rmse:0.394011
#
# [168]	validation_0-rmse:0.392607	validation_1-rmse:0.393823
#
# [169]	validation_0-rmse:0.392503	validation_1-rmse:0.39371
#
# [170]	validation_0-rmse:0.392503	validation_1-rmse:0.39371
#
# [171]	validation_0-rmse:0.392503	validation_1-rmse:0.39371
#
# [172]	validation_0-rmse:0.392366	validation_1-rmse:0.393589
#
# [173]	validation_0-rmse:0.392366	validation_1-rmse:0.393589
#
# [174]	validation_0-rmse:0.392366	validation_1-rmse:0.393589
#
# [175]	validation_0-rmse:0.392366	validation_1-rmse:0.393589
#
# [176]	validation_0-rmse:0.392366	validation_1-rmse:0.393589
#
# [177]	validation_0-rmse:0.392366	validation_1-rmse:0.393589
#
# [178]	validation_0-rmse:0.392366	validation_1-rmse:0.393589
#
# [179]	validation_0-rmse:0.392366	validation_1-rmse:0.393589
#
# [180]	validation_0-rmse:0.392366	validation_1-rmse:0.393589
#
# [181]	validation_0-rmse:0.392366	validation_1-rmse:0.393589
#
# [182]	validation_0-rmse:0.392366	validation_1-rmse:0.393589
#
# Stopping. Best iteration:
# [172]	validation_0-rmse:0.392366	validation_1-rmse:0.393589
#
#
# SCORE:
# 0.15491225855639865
# 100%|██████████| 200/200 [1:11:44<00:00, 21.52s/it, best loss: 0.08635087600383438]

# %%
print(best_hyperparams)
# Out:
# {'gamma': 0.05377479647174427, 'learning_rate': 0.09848124196860411, 'max_depth': 8.417877590083625, 'min_child_weight': 6.0, 'n_estimators': 450.0, 'reg_alpha': 0.0, 'reg_lambda': 0.89348051742, 'subsample': 0.75}

# %% [markdown]
# {'gamma': 0.05377479647174427, 'learning_rate': 0.09848124196860411, 'max_depth': 8.417877590083625, 'min_child_weight': 6.0, 'n_estimators': 450.0, 'reg_alpha': 0.0, 'reg_lambda': 0.89348051742, 'subsample': 0.75}

# %%
clf21 = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=450, learning_rate = 0.09848124196860411,
                         max_depth=8, gamma= 0.05377479647174427, reg_lambda=  0.89348051742,
                         reg_alpha=0, min_child_weight=6, colsample_bytree=1, subsample=0.75)
#0.08676238917490152
#clf21 = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=500, learning_rate = 0.10013642773246478,
                         #max_depth=9, gamma=8.370004832886828, reg_lambda= 0.8186408519778837,
                         #reg_alpha=90, min_child_weight=8, colsample_bytree=0.5973212942576718, subsample=0.7)
#0.2180151843695646

#clf21 = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=500, learning_rate = 0.05237294372499705,
                         #max_depth=7, gamma=0.02276270423454086, reg_lambda= 0,
                         #reg_alpha=0, min_child_weight=4, colsample_bytree=0.5973212942576718, subsample=0.75)
#0.08920955079232559

clf21.fit(X_train, y_train)
yh21 = clf21.predict(X_test)
print(mean_squared_error(y_test, yh21))
# Out:
# 0.08334695703550886

# %%
yh21[yh21 > 5] = 5
y_actual = pt.inverse_transform(pd.DataFrame(y_test, columns=['sold_price'])) * 100
yh21_actual = pt.inverse_transform(pd.DataFrame(yh21,columns=['sold_price']))  * 100
print(mean_absolute_error(y_actual, yh21_actual))
print(np.sqrt(mean_squared_error(y_actual, yh21_actual)))
# Out:
# 152639.93299598258
# 358174.22039910156

# %%
plt.scatter(y_actual, yh21_actual)
plt.xlabel('Actual Test Value')
plt.ylabel('Predicted Value')
# Out:
# Text(0, 0.5, 'Predicted Value')

# %%
fig, ax = plt.subplots(figsize=(30, 30))
xgb.plot_tree(clf21, num_trees=4, ax=ax)
plt.show()
plt.savefig('test.pdf')
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.802601 to fit

# %%
feature_important = clf21.get_booster().get_score(importance_type='weight')
keys = list(feature_important.keys())
values = list(feature_important.values())
print(keys)
print(values)

data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=False)
data.nlargest(40, columns="score").plot(kind='barh', figsize = (20,10)) ## plot top 40 features
# Out:
# ['bedroom', 'bathroom', 'mean_income', 'sqft', 'Dist', 'Line_Yonge-University-Spadina', 'Line_Sheppard', 'Line_Bloor-Danforth', 'type_Condo', 'parking', 'type_Condo Special', 'type_Detached', 'type_Townhouse', 'type_Co Op Apt', 'type_Plex']
# [2102, 2055, 7250, 5060, 18419, 440, 253, 767, 737, 2554, 277, 450, 385, 68, 68]
